# %% [markdown]
# # Analyse des données textuelles

# %%
import os
import re
import pandas as pd

# %% [markdown]
# #### Importer la base de données

# %%
df = pd.read_csv('DF_JOB.csv', sep=';', encoding='cp1252')

# %%
df.head(3)
# Out:
#    Unnamed: 0                                              TITRE  \
# 0           1  rpa & data : automatisation des flux de donnée...
# 1           2                                 data scientist f/h
# 2           3                         data engineer sénior (f/h)
#
#                                          DESCRIPTION       ENTREPRISE  \
# 0  description de l'entreprise almond recherche d...           almond
# 1  l'entreprise leader de son marché, le groupe p...  réseau primever
# 2  description de l'entreprise asendit est spécia...          asendit
#
#                     LIEUX
# 0  sèvres, hauts-de-seine
# 1    agen, lot-et-garonne
# 2                    lyon

# %% [markdown]
# ####  Nettoyage et préparation de la base de données

# %%
del df['Unnamed: 0']

# %%
df.head(3)
# Out:
#                                                TITRE  \
# 0  rpa & data : automatisation des flux de donnée...
# 1                                 data scientist f/h
# 2                         data engineer sénior (f/h)
#
#                                          DESCRIPTION       ENTREPRISE  \
# 0  description de l'entreprise almond recherche d...           almond
# 1  l'entreprise leader de son marché, le groupe p...  réseau primever
# 2  description de l'entreprise asendit est spécia...          asendit
#
#                     LIEUX
# 0  sèvres, hauts-de-seine
# 1    agen, lot-et-garonne
# 2                    lyon

# %%
df.shape
# Out:
# (2000, 4)

# %%
def func(a):
    if "analyst" in a.lower():
        return "data analyst"
    elif "scientist" in a.lower():
        return "data scientist"
    elif "engineer" in a.lower():
        return "data engineer"
    elif "data science" in a.lower():
        return "data scientist"
    elif "bi " in a.lower():
        return "bi"
    elif "business intelligence" in a.lower():
        return "bi"
    elif "officer" in a.lower():
        return "data officer"
    elif "architect" in a.lower():
        return "data architect"
    elif "big data" in a.lower():
        return "ingénieur big data"
    elif "consultant" in a.lower():
        return "consultant data"
    elif "manager" in a.lower():
        return "data manager"
    elif "steward" in a.lower():
        return "data steward"
    else:
        return "Other"

df["POSTE"] = df.TITRE.apply(lambda x: func(x))

# %%
df.head(5)
# Out:
#                                                TITRE  \
# 0  rpa & data : automatisation des flux de donnée...
# 1                                 data scientist f/h
# 2                         data engineer sénior (f/h)
# 3                                   data analyst f/h
# 4                                 data scientist f/h
#
#                                          DESCRIPTION       ENTREPRISE  \
# 0  description de l'entreprise almond recherche d...           almond
# 1  l'entreprise leader de son marché, le groupe p...  réseau primever
# 2  description de l'entreprise asendit est spécia...          asendit
# 3  description de l'entreprise aventure entrepren...     voyage privé
# 4  leader de son marché, le groupe primever dével...  réseau primever
#
#                     LIEUX           POSTE
# 0  sèvres, hauts-de-seine           Other
# 1    agen, lot-et-garonne  data scientist
# 2                    lyon   data engineer
# 3         aix-en-provence    data analyst
# 4    agen, lot-et-garonne  data scientist

# %% [markdown]
# #### Les métiers data recherchés

# %%
df['POSTE'].value_counts()
# Out:
# Other                 557
# data analyst          425
# data engineer         301
# data scientist        248
# consultant data       132
# data manager          117
# data architect         73
# ingénieur big data     69
# bi                     55
# data officer           15
# data steward            8
# Name: POSTE, dtype: int64

# %% [markdown]
# #### Préparation des données textuelles de la colonne 'DESCRIPTION'

# %%
list_analyst = df.loc[df['POSTE'] == 'data analyst', 'DESCRIPTION'].values
list_scientist = df.loc[df['POSTE'] == 'data scientist', 'DESCRIPTION']. values
list_engineer = df.loc[df['POSTE'] == 'data engineer', 'DESCRIPTION']. values

# %%
len(list_analyst)
# Out:
# 425

# %%
list_analyst = " ".join(list_analyst)
list_scientist = " ".join(list_scientist)
list_engineer = " ".join(list_engineer)

# %% [markdown]
# ##### Nettoyage du texte des caractères spéciaux

# %%
list_analyst = re.sub(r"[.´`:' ;,?=0123456789+@*–<>%»«^,)(#!/\-•]+"," ",list_analyst) 
list_scientist = re.sub(r"[.´`:' ;,?=0123456789+@*–<>%»«^,)(#!/\-•]+"," ",list_scientist) 
list_engineer = re.sub(r"[.´`:' ;,?=0123456789+@*–<>%»«^,)(#!/\-•]+"," ",list_engineer)

# %%
Poste = ['Data analyst', 'Data scientist', 'Data engineer']

# %%
description = [list_analyst, list_scientist, list_engineer]

# %%
nt = len(Poste)  
d = ' '.join(description)
e = d.split()

# %% [markdown]
# #### création du dictionnaire "motot" pour associer chaque mot à son effectif

# %%
motot={}

# %%
for mot in e:
	motot[mot] = 0  
for  mot in e:
	motot[mot] += 1

# %%
motot
# Out:
# {'description': 480,
#  'de': 32398,
#  'l': 6562,
#  'entreprise': 902,
#  'aventure': 149,
#  'entrepreneuriale': 11,
#  'lancée': 17,
#  'en': 9299,
#  'france': 711,
#  'voyage': 42,
#  'privé': 20,
#  'est': 2744,
#  'le': 6362,
#  'leader': 222,
#  'européen': 98,
#  'la': 11733,
#  'vente': 98,
#  'éphémère': 3,
#  'ligne': 67,
#  'ce': 1135,
#  'qui': 1531,
#  'nous': 3332,
#  'anime': 18,
#  'faire': 683,
#  'voyager': 4,
#  'nos': 2422,
#  'millions': 142,
#  'membres': 76,
#  'dénichant': 3,
#  'des': 13185,
#  'produits': 381,
#  'haut': 73,
#  'gamme': 58,
#  'au': 3554,
#  'meilleur': 74,
#  'prix': 43,
#  'sommes': 455,
#  'présents': 40,
#  'sur': 3622,
#  'neuf': 18,
#  'marchés': 109,
#  'et': 20091,
#  'ne': 182,
#  'comptons': 15,
#  'pas': 350,
#  's’arrêter': 3,
#  'là': 91,
#  'collaborateurs': 697,
#  'sont': 964,
#  'ambitieux': 80,
#  'se': 540,
#  'passionné': 121,
#  'e': 1325,
#  's': 624,
#  'exigeant': 22,
#  'tous': 572,
#  'ont': 140,
#  'un': 5496,
#  'rôle': 234,
#  'à': 8688,
#  'jouer': 17,
#  'individuellement': 4,
#  'collectivement': 4,
#  'rejoindre': 481,
#  'groupe': 1200,
#  'c’est': 207,
#  'aussi': 359,
#  'intégrer': 210,
#  'projet': 620,
#  'collectif': 33,
#  'où': 271,
#  'œuvrons': 5,
#  'renforcer': 81,
#  'notre': 1803,
#  'ancrage': 6,
#  'local': 29,
#  'service': 495,
#  'du': 4911,
#  'développement': 1142,
#  'territoire': 57,
#  'croyons': 13,
#  'possibilité': 152,
#  'changer': 19,
#  'trajectoires': 3,
#  'sortir': 7,
#  'déterminismes': 3,
#  'sociaux': 37,
#  'économiques': 13,
#  'campus': 16,
#  'rassemble': 19,
#  'salariés': 77,
#  'sportifs': 15,
#  'niveau': 629,
#  'éducateurs': 3,
#  'chacun': 170,
#  'apprenant': 4,
#  'autres': 281,
#  'pour': 5083,
#  'développer': 562,
#  'lui': 34,
#  'même': 120,
#  'impacter': 3,
#  'positivement': 17,
#  'concrétisons': 7,
#  'engagements': 59,
#  'devenant': 8,
#  'mission': 648,
#  'avec': 3191,
#  'objectif': 184,
#  'ensemble': 374,
#  'provoquer': 3,
#  'les': 9018,
#  'possibles': 32,
#  'poste': 1302,
#  'pourquoi': 170,
#  'recrutons': 78,
#  'univers': 56,
#  'terrain': 52,
#  'jeu': 34,
#  'magique': 2,
#  'termes': 60,
#  'data': 5830,
#  'données': 3696,
#  'clients': 1347,
#  'marketing': 515,
#  'fournisseurs': 39,
#  'navigation': 25,
#  'crm': 136,
#  'client': 657,
#  'activité': 258,
#  'génère': 8,
#  'important': 79,
#  'volume': 36,
#  'to': 444,
#  'dont': 207,
#  'analyse': 948,
#  'a': 1034,
#  'impact': 143,
#  'direct': 45,
#  'expérience': 1274,
#  'utilisateur': 39,
#  'conversion': 14,
#  'relations': 42,
#  'montons': 2,
#  'une': 4912,
#  'nouvelle': 130,
#  'organisation': 240,
#  'ouvrons': 3,
#  'plusieurs': 299,
#  'postes': 96,
#  'clés': 135,
#  'écrire': 30,
#  'page': 57,
#  'tant': 407,
#  'que': 1895,
#  'analyst': 503,
#  'vous': 7370,
#  'serez': 327,
#  'charge': 342,
#  'identification': 77,
#  'leviers': 48,
#  'croissance': 247,
#  'rentabilité': 25,
#  'accompagnant': 18,
#  'prise': 264,
#  'décision': 147,
#  'différents': 410,
#  'départements': 34,
#  'produit': 160,
#  'achats': 58,
#  'sales': 48,
#  'transport': 141,
#  'finance': 231,
#  'amené': 146,
#  'maîtriser': 22,
#  'tout': 571,
#  'traitement': 418,
#  'donnée': 493,
#  'sera': 271,
#  'indispensable': 104,
#  'tracking': 23,
#  'adapté': 26,
#  'collecte': 138,
#  'fiable': 25,
#  'indicateurs': 208,
#  'pertinents': 45,
#  'modèle': 147,
#  'performant': 16,
#  'visualisations': 19,
#  'adaptées': 57,
#  'analyses': 417,
#  'b': 133,
#  'tests': 172,
#  'concluants': 1,
#  'missions': 982,
#  'monitorer': 20,
#  'performance': 404,
#  'ventes': 54,
#  'campagnes': 79,
#  'analyser': 279,
#  'plus': 2013,
#  'demandés': 6,
#  'par': 1640,
#  'visiteurs': 5,
#  'identifier': 182,
#  'destinations': 2,
#  'tendance': 11,
#  'alerter': 6,
#  'business': 720,
#  'cas': 234,
#  'comportement': 36,
#  'inattendu': 1,
#  'source': 78,
#  'problème': 31,
#  'recommander': 7,
#  'solution': 215,
#  'définir': 187,
#  'l’objectif': 19,
#  'l’a': 2,
#  'test': 85,
#  'périmètre': 93,
#  'permettant': 286,
#  'd’obtenir': 3,
#  'résultats': 274,
#  'rapides': 9,
#  'fiables': 31,
#  'limitant': 1,
#  'risques': 165,
#  'kpis': 40,
#  'suivre': 117,
#  'mesurer': 39,
#  'efficacement': 24,
#  'impacts': 45,
#  'potentiels': 21,
#  'réaliser': 277,
#  'basées': 31,
#  'significativité': 2,
#  'recommandations': 87,
#  'd': 7645,
#  'actions': 152,
#  'ad': 56,
#  'hoc': 53,
#  'exploratoires': 12,
#  'améliorer': 208,
#  'compréhension': 180,
#  'd’un': 298,
#  'domaine': 434,
#  'd’une': 354,
#  'situation': 184,
#  'opportunités': 144,
#  'croissances': 1,
#  'traduire': 43,
#  'plan': 195,
#  'd’actions': 10,
#  'problématiques': 246,
#  'non': 252,
#  'maîtrisées': 1,
#  'date': 142,
#  'parler': 27,
#  'y': 215,
#  'répondre': 263,
#  'environnement': 777,
#  'technique': 498,
#  'tableau': 198,
#  'dataiku': 66,
#  'dss': 6,
#  'bigquery': 57,
#  'elasticsearch': 38,
#  'etl': 163,
#  'interne': 194,
#  'apache': 19,
#  'spark': 227,
#  'on': 202,
#  'yarn': 3,
#  'google': 139,
#  'cloud': 591,
#  'storage': 18,
#  'dataproc': 10,
#  'pub': 10,
#  'sub': 7,
#  'python': 741,
#  'scala': 125,
#  'docker': 93,
#  'github': 36,
#  'gitlabqualificationsformation': 1,
#  'supérieure': 110,
#  'bac': 680,
#  'école': 275,
#  'd’ingénieur': 90,
#  'ou': 2446,
#  'spécialisation': 174,
#  'statistiques': 417,
#  'avez': 1077,
#  'minimum': 289,
#  'ans': 514,
#  'd’expérience': 63,
#  'dans': 4771,
#  'l’analyse': 67,
#  'digital': 306,
#  'êtes': 1076,
#  'reconnu': 104,
#  'votre': 1928,
#  'rigueur': 204,
#  'excellent': 40,
#  'sens': 318,
#  'bon': 319,
#  'relationnel': 133,
#  'aimez': 165,
#  'travailler': 571,
#  'équipe': 1609,
#  'notions': 63,
#  'sql': 609,
#  'maîtrisez': 194,
#  'outil': 225,
#  'bi': 414,
#  'marché': 291,
#  'forte': 276,
#  'fort': 124,
#  'esprit': 394,
#  'analytique': 103,
#  'bases': 317,
#  'solides': 71,
#  'statistique': 94,
#  'savez': 176,
#  'communiquer': 102,
#  'clairement': 5,
#  'vos': 1213,
#  'd’analyses': 24,
#  'synthèse': 193,
#  'l’intérêt': 3,
#  'nouveaux': 360,
#  'langages': 190,
#  'tels': 87,
#  'r': 186,
#  'proposer': 206,
#  'nouvelles': 353,
#  'idées': 68,
#  'avancer': 14,
#  'informations': 313,
#  'supplémentaires': 56,
#  'journey': 11,
#  'grandir': 86,
#  'équipes': 1048,
#  'dynamique': 272,
#  'exposé': 3,
#  'l’international': 27,
#  'être': 679,
#  'entièrement': 10,
#  'impliqué': 28,
#  'l’aventure': 23,
#  'devenir': 73,
#  'acteur': 196,
#  'réussite': 78,
#  'participation': 147,
#  'vivre': 83,
#  'sud': 21,
#  'cadre': 531,
#  'naturel': 30,
#  'économique': 39,
#  'culturel': 4,
#  'exceptionnel': 13,
#  's’impliquer': 3,
#  'projets': 1119,
#  'sociétaux': 20,
#  'orientés': 13,
#  'éducation': 25,
#  'sport': 83,
#  'ecole': 96,
#  'xv': 4,
#  'vp': 9,
#  'green': 14,
#  'accompagner': 376,
#  'start': 58,
#  'up': 101,
#  'accélérateur': 11,
#  'tremplins': 3,
#  'innovation': 311,
#  'tourisme': 8,
#  'bénéficier': 54,
#  'tarifs': 16,
#  'encore': 156,
#  'avantageux': 14,
#  'sites': 85,
#  'profiter': 34,
#  'famille': 39,
#  'amis': 6,
#  'participer': 453,
#  'collègues': 63,
#  'aux': 1560,
#  'cours': 121,
#  'offerts': 13,
#  'matchs': 3,
#  'rugby': 6,
#  'provence': 10,
#  'enfin': 94,
#  'nombreux': 120,
#  'évènements': 35,
#  'internes': 241,
#  'company': 65,
#  'breaks': 3,
#  'mensuels': 29,
#  'convention': 27,
#  'annuelle': 20,
#  'etc': 463,
#  'rythment': 10,
#  'vie': 269,
#  'euro': 6,
#  'information': 260,
#  'filiale': 115,
#  'technologique': 264,
#  'crédit': 295,
#  'mutuel': 10,
#  'alliance': 9,
#  'fédérale': 2,
#  'conçoit': 20,
#  'réalise': 22,
#  'maintient': 11,
#  'exploite': 9,
#  'système': 150,
#  'd’information': 55,
#  'commun': 51,
#  'utilisé': 28,
#  'activités': 420,
#  'production': 432,
#  'informatique': 389,
#  'national': 35,
#  'international': 319,
#  'assurées': 1,
#  'environ': 22,
#  'répartis': 48,
#  'géographiques': 31,
#  'strasbourg': 7,
#  'nancy': 1,
#  'dijon': 5,
#  'orléans': 3,
#  'lyon': 80,
#  'lille': 64,
#  'cergy': 1,
#  'val': 6,
#  'fontenay': 1,
#  'paris': 373,
#  'nantes': 77,
#  'l’arrivée': 2,
#  'maturité': 10,
#  'solutions': 934,
#  'informatiques': 108,
#  'automatique': 54,
#  'langage': 204,
#  'ainsi': 528,
#  'qu’un': 16,
#  'apprentissage': 126,
#  'l’exemple': 1,
#  'ouvert': 88,
#  'perspectives': 39,
#  'mieux': 175,
#  'assister': 27,
#  'servir': 15,
#  'leurs': 528,
#  'donc': 71,
#  'décidé': 9,
#  'd’investir': 1,
#  'fortement': 31,
#  'l’informatique': 11,
#  'cognitive': 2,
#  'avons': 186,
#  'été': 85,
#  'première': 192,
#  'mettre': 432,
#  'œuvre': 317,
#  'technologie': 139,
#  'ibm': 7,
#  'watson': 2,
#  'dites': 3,
#  'cognitives': 3,
#  'déployées': 11,
#  'assistants': 2,
#  'virtuels': 2,
#  'chatbot': 5,
#  'analyseurs': 1,
#  'd’emails': 1,
#  'assistant': 12,
#  'vocal': 2,
#  'téléphonique': 18,
#  'sein': 1004,
#  'secteur': 234,
#  'innovant': 57,
#  'rejoignez': 302,
#  'l’équipe': 247,
#  'exploitation': 202,
#  'architectures': 73,
#  'l’architecture': 37,
#  'applicative': 9,
#  'créer': 211,
#  'outils': 1088,
#  'récoltées': 4,
#  'd’enrichir': 4,
#  'processus': 412,
#  'métiers': 836,
#  'selon': 159,
#  'ces': 436,
#  'composants': 47,
#  'déclinent': 7,
#  'technologies': 511,
#  'c': 581,
#  'serveur': 3,
#  'nosql': 97,
#  'kibana': 17,
#  'kafka…': 2,
#  'intégré': 105,
#  'dizaine': 16,
#  'personnes': 343,
#  'seront': 274,
#  'relation': 134,
#  'gestion': 679,
#  'précisément': 20,
#  'concevoir': 222,
#  'rédiger': 91,
#  'spécifications': 99,
#  'fonctionnelles': 105,
#  'applicatives': 24,
#  'techniques': 735,
#  'applications': 214,
#  'intranet': 3,
#  'd’exploration': 4,
#  'restitution': 84,
#  'modéliser': 71,
#  'décisionnel': 52,
#  'dashboard': 63,
#  'apporter': 118,
#  'support': 216,
#  'organiser': 84,
#  'recette': 79,
#  'gérer': 151,
#  'demandes': 53,
#  'd’évolution': 25,
#  'mode': 95,
#  'respect': 150,
#  'management': 380,
#  'qualité': 610,
#  'allez': 27,
#  'chez': 508,
#  'noustélétravail': 1,
#  'jours': 206,
#  'semaine': 110,
#  'rémunération': 109,
#  'fixe': 34,
#  'versée': 1,
#  'mois': 379,
#  'rtt': 65,
#  'intéressement': 41,
#  'abondement': 5,
#  'épargne': 38,
#  'perco': 1,
#  'contrat': 361,
#  'santé': 226,
#  'prévoyance': 44,
#  'retraite': 25,
#  'supplémentaire': 6,
#  'l’employeur': 4,
#  'conditions': 69,
#  'bancaires': 44,
#  'assurances': 75,
#  'préférentielles': 2,
#  'politique': 135,
#  'parentale': 2,
#  'avantageuse': 7,
#  'allons': 7,
#  'aimer': 5,
#  'issu': 57,
#  'formation': 733,
#  'maitrisez': 91,
#  'base': 262,
#  'orientée': 28,
#  'programmation': 183,
#  'objet': 14,
#  'type': 404,
#  'plaira': 4,
#  'alors': 214,
#  'bien': 363,
#  'évidemment': 8,
#  'préférera': 4,
#  'curieux': 163,
#  'innovations': 27,
#  'technologiques': 132,
#  'prêt': 65,
#  'relever': 93,
#  'défis': 100,
#  'faisant': 17,
#  'preuve': 173,
#  'd’écoute': 16,
#  'car': 36,
#  'permettra': 99,
#  'mener': 115,
#  'également': 311,
#  'capacités': 164,
#  'd’analyse': 122,
#  'souci': 27,
#  'normes': 28,
#  'standards': 72,
#  'appréciez': 40,
#  'apprendre': 81,
#  'mais': 235,
#  'collaboration': 263,
#  'cette': 526,
#  'offre': 419,
#  'faite': 14,
#  'complémentaires': 128,
#  'basé': 135,
#  'pourvoir': 75,
#  'cdi': 293,
#  'dès': 104,
#  'possible': 199,
#  'faisons': 25,
#  'connaissance': 584,
#  'régie': 11,
#  'plurimédia': 2,
#  'tf': 27,
#  'publicité': 18,
#  'commercialise': 18,
#  'espaces': 22,
#  'publicitaires': 20,
#  'supports': 41,
#  'médias': 29,
#  'télévision': 12,
#  'écrans': 4,
#  'classique': 5,
#  'dispositifs': 42,
#  'parrainage': 5,
#  'chaînes': 20,
#  'tmc': 4,
#  'tfx': 4,
#  'séries': 24,
#  'films': 12,
#  'lci': 4,
#  'tv': 19,
#  'breizh': 2,
#  'ushuaïa': 2,
#  'histoire': 12,
#  'depuis': 287,
#  'peu': 25,
#  'chaîne': 97,
#  'réunionnaise': 2,
#  'antenne': 4,
#  'réunion': 3,
#  'radios': 7,
#  'indés': 2,
#  'm': 76,
#  'radio': 4,
#  'outre': 27,
#  'mer': 6,
#  'autour': 238,
#  'déclinaisons': 2,
#  'digitales': 63,
#  'commercialisées': 3,
#  'assets': 8,
#  'digitaux': 43,
#  'mytf': 3,
#  'poursuivant': 2,
#  'déploiement': 181,
#  'stratégie': 264,
#  'digitale': 237,
#  'pc': 6,
#  'mobile': 63,
#  'tablette': 2,
#  'travers': 245,
#  'diversité': 288,
#  'attractivité': 5,
#  'propose': 95,
#  'ses': 909,
#  'annonceurs': 12,
#  'modes': 33,
#  'expression': 25,
#  'différenciés': 2,
#  'adaptés': 39,
#  'besoins': 552,
#  'revenu': 6,
#  'piloter': 90,
#  'inventaires': 6,
#  'offres': 191,
#  'adserving': 2,
#  'afin': 643,
#  'opérer': 15,
#  'appliquer': 28,
#  'analyste': 70,
#  'aura': 53,
#  'suivantes': 260,
#  'suivi': 420,
#  'audiences': 11,
#  'reporting': 184,
#  'replay': 5,
#  'segmentée…': 2,
#  'vidéos': 4,
#  'vues': 6,
#  'remplissage': 2,
#  'impressions': 4,
#  'maintenance': 166,
#  'adserver': 2,
#  'freewheel': 4,
#  'assurer': 443,
#  'correcte': 2,
#  'diffusion': 50,
#  'mise': 718,
#  'jour': 213,
#  'commerciaux': 66,
#  'avant': 130,
#  'disponible': 23,
#  'réservation': 3,
#  'ops': 19,
#  'sponsoring': 6,
#  'adserve': 1,
#  'localisation': 154,
#  'boulogne': 20,
#  'billancourt': 12,
#  'atouts': 72,
#  'différencevous': 2,
#  'préparez': 59,
#  'economie': 4,
#  'revenue': 4,
#  'commerce': 184,
#  'université': 105,
#  'équivalent': 114,
#  'maitriser': 11,
#  'excellente': 30,
#  'maîtrise': 429,
#  'excel': 131,
#  'software': 54,
#  'objects': 10,
#  'aise': 76,
#  'adservers': 2,
#  'dfp': 2,
#  'faites': 104,
#  'raisonnement': 5,
#  'structuré': 23,
#  'réelle': 68,
#  'capacité': 520,
#  'transversalité': 9,
#  'fonctionnement': 103,
#  'aisance': 73,
#  'relationnelle': 69,
#  'adaptation': 60,
#  'travail': 758,
#  'font': 108,
#  'partie': 214,
#  'mène': 9,
#  'engagée': 59,
#  'garantir': 124,
#  'équité': 19,
#  'ouverts': 85,
#  'handicap': 206,
#  'région': 70,
#  'île': 20,
#  'recherche': 450,
#  'responsable': 272,
#  'professionnelle': 185,
#  'ptn': 2,
#  'pôle': 187,
#  'transformation': 454,
#  'numérique': 187,
#  'direction': 412,
#  'sous': 223,
#  'responsabilité': 135,
#  'pilote': 22,
#  'liés': 83,
#  'feuille': 27,
#  'route': 35,
#  'pfpa': 2,
#  'il': 565,
#  'assure': 61,
#  'appui': 33,
#  'documentation': 117,
#  'modélisation': 270,
#  'liée': 12,
#  'titre': 80,
#  'elle': 266,
#  'accompagne': 124,
#  'chefs': 34,
#  'leur': 728,
#  'apporte': 47,
#  'conseil': 242,
#  'expert': 71,
#  'ressources': 96,
#  'cohérence': 60,
#  'lignes': 27,
#  'directrices': 6,
#  'liées': 75,
#  'gouvernance': 106,
#  'compétence': 129,
#  'régionale': 22,
#  'carif': 1,
#  'recensement': 4,
#  'l’offre': 23,
#  'sa': 394,
#  'dimension': 40,
#  'chantiers': 21,
#  'applicatifs': 25,
#  'equiper': 2,
#  'métier': 644,
#  'cartographie': 34,
#  'l’identification': 20,
#  'sources': 189,
#  'référentiels': 30,
#  'maîtres': 6,
#  'appuyer': 9,
#  'formalisation': 11,
#  'prioritaires': 5,
#  'l’outillage': 1,
#  'd’assurer': 19,
#  'l’intégrité': 5,
#  'sécurité': 196,
#  'conduire': 21,
#  'renforcement': 28,
#  'place': 692,
#  'décisionnels': 34,
#  'datawarehouses': 3,
#  'datamarts': 13,
#  'tableaux': 172,
#  'bord': 179,
#  'lien': 196,
#  'profilcompétences': 3,
#  'requises': 100,
#  'enjeux': 264,
#  'cycle': 109,
#  'conceptuelle': 5,
#  'n’est': 17,
#  'requise': 32,
#  'savoir': 299,
#  'méthodologiques': 13,
#  'matière': 121,
#  'numériques': 94,
#  'utilisateurs': 211,
#  'poser': 2,
#  'rapidement': 65,
#  'diagnostic': 16,
#  'fonctionnels': 56,
#  'limites': 26,
#  'avérée': 17,
#  'aptitude': 17,
#  'stratégique': 121,
#  'force': 299,
#  'proposition': 284,
#  'd’initiative': 25,
#  'goût': 82,
#  'l’action': 5,
#  'l’innovation': 47,
#  'l’usager': 1,
#  'public': 82,
#  'pédagogie': 36,
#  'l’explication': 1,
#  'spécialistes': 66,
#  'pro': 36,
#  'autonomie': 224,
#  'adaptabilité': 27,
#  'dynamisme': 55,
#  'réactivité': 50,
#  'sauf': 5,
#  'mention': 2,
#  'durée': 176,
#  'déterminée': 5,
#  'cdd': 32,
#  'cet': 39,
#  'emploi': 93,
#  'priorité': 23,
#  'agents': 49,
#  'titulaires': 4,
#  'fonction': 198,
#  'publique': 19,
#  'voie': 10,
#  'mutation': 17,
#  'détachement': 6,
#  'inscrits': 6,
#  'liste': 18,
#  'qu’aux': 6,
#  'contractuels': 9,
#  'décret': 2,
#  'n°': 31,
#  'février': 24,
#  'pris': 36,
#  'application': 157,
#  'article': 22,
#  'loi': 6,
#  'janvier': 89,
#  'modifiée': 3,
#  'portant': 9,
#  'dispositions': 3,
#  'statutaires': 2,
#  'relatives': 24,
#  'territoriale': 6,
#  'relatif': 3,
#  'construisons': 31,
#  'lieu': 122,
#  'demain': 162,
#  'installée': 7,
#  'l’éco': 4,
#  'quartier': 5,
#  'docks': 3,
#  'saint': 68,
#  'ouen': 7,
#  'bâtiment': 49,
#  'hqe': 4,
#  'télétravail': 328,
#  'salle': 48,
#  'services…': 2,
#  'réinventé': 2,
#  'confiance': 111,
#  'humaines': 48,
#  'active': 38,
#  'ile': 80,
#  'lutte': 46,
#  'contre': 45,
#  'toutes': 296,
#  'formes': 20,
#  'discriminations': 7,
#  'vise': 14,
#  'diversifier': 10,
#  'candidatures': 41,
#  'reconnaît': 9,
#  'talents': 229,
#  'handi': 12,
#  'accessible': 54,
#  'régional': 13,
#  'mondial': 135,
#  'relay': 4,
#  'qu': 306,
#  'simple': 42,
#  'colis': 4,
#  'offrons': 74,
#  'expédition': 1,
#  'livraison': 46,
#  'rapide': 28,
#  'vertueux': 11,
#  'réseau': 223,
#  'points': 53,
#  'relais': 6,
#  'lockers': 1,
#  'créateur': 20,
#  'liens': 9,
#  'entre': 244,
#  'commerçants': 17,
#  'consommateurs': 57,
#  'précurseurs': 1,
#  'tendances': 50,
#  'écoute': 66,
#  'portés': 3,
#  'contexte': 215,
#  'constant': 8,
#  'hors': 36,
#  'domicile': 8,
#  'ambitionnons': 2,
#  'étendre': 13,
#  'préférence': 19,
#  'challenge': 62,
#  'basés': 25,
#  'relèvent': 1,
#  'passion': 104,
#  'accomplissement': 3,
#  'collaboratifs': 17,
#  'ambiance': 51,
#  'pleine': 65,
#  'pep': 1,
#  'recherchons': 227,
#  'futur': 132,
#  'relayeuses': 2,
#  'relayeurs': 2,
#  'prendre': 135,
#  'part': 95,
#  'suite': 58,
#  'côtés': 54,
#  'si': 532,
#  'comme': 356,
#  'convaincu': 28,
#  'n': 229,
#  'attendez': 22,
#  'découvrez': 11,
#  'prochain': 27,
#  'h': 495,
#  'f': 413,
#  'excellence': 116,
#  'opérationnelle': 119,
#  'évoluer': 267,
#  'process': 212,
#  'globale': 64,
#  'notamment': 260,
#  'celle': 30,
#  'relative': 14,
#  'amélioration': 167,
#  'efficience': 15,
#  'opérations': 111,
#  'cœur': 294,
#  'directions': 103,
#  'opération': 13,
#  'industrielle': 43,
#  'soutenez': 3,
#  'activement': 59,
#  'directeurs': 10,
#  'industriel': 71,
#  'initiatives': 77,
#  'stratégiques': 88,
#  'visant': 66,
#  'continue': 120,
#  'opérationnels': 81,
#  ...}

# %%
print("la longueur du dictionnaire est :",len(motot), "mots")
# Out:
# la longueur du dictionnaire est : 16875 mots

# %% [markdown]
# ##### Associer chaque mot à son effectif dans les troix objets : "list_analyst, list_sientist, list_engineer" stocker dans l'objet "description"

# %%
motex = {}

# %%
for mot in motot:
    motex[mot] = [0]*nt

# %%
motex
# Out:
# {'description': [0, 0, 0],
#  'de': [0, 0, 0],
#  'l': [0, 0, 0],
#  'entreprise': [0, 0, 0],
#  'aventure': [0, 0, 0],
#  'entrepreneuriale': [0, 0, 0],
#  'lancée': [0, 0, 0],
#  'en': [0, 0, 0],
#  'france': [0, 0, 0],
#  'voyage': [0, 0, 0],
#  'privé': [0, 0, 0],
#  'est': [0, 0, 0],
#  'le': [0, 0, 0],
#  'leader': [0, 0, 0],
#  'européen': [0, 0, 0],
#  'la': [0, 0, 0],
#  'vente': [0, 0, 0],
#  'éphémère': [0, 0, 0],
#  'ligne': [0, 0, 0],
#  'ce': [0, 0, 0],
#  'qui': [0, 0, 0],
#  'nous': [0, 0, 0],
#  'anime': [0, 0, 0],
#  'faire': [0, 0, 0],
#  'voyager': [0, 0, 0],
#  'nos': [0, 0, 0],
#  'millions': [0, 0, 0],
#  'membres': [0, 0, 0],
#  'dénichant': [0, 0, 0],
#  'des': [0, 0, 0],
#  'produits': [0, 0, 0],
#  'haut': [0, 0, 0],
#  'gamme': [0, 0, 0],
#  'au': [0, 0, 0],
#  'meilleur': [0, 0, 0],
#  'prix': [0, 0, 0],
#  'sommes': [0, 0, 0],
#  'présents': [0, 0, 0],
#  'sur': [0, 0, 0],
#  'neuf': [0, 0, 0],
#  'marchés': [0, 0, 0],
#  'et': [0, 0, 0],
#  'ne': [0, 0, 0],
#  'comptons': [0, 0, 0],
#  'pas': [0, 0, 0],
#  's’arrêter': [0, 0, 0],
#  'là': [0, 0, 0],
#  'collaborateurs': [0, 0, 0],
#  'sont': [0, 0, 0],
#  'ambitieux': [0, 0, 0],
#  'se': [0, 0, 0],
#  'passionné': [0, 0, 0],
#  'e': [0, 0, 0],
#  's': [0, 0, 0],
#  'exigeant': [0, 0, 0],
#  'tous': [0, 0, 0],
#  'ont': [0, 0, 0],
#  'un': [0, 0, 0],
#  'rôle': [0, 0, 0],
#  'à': [0, 0, 0],
#  'jouer': [0, 0, 0],
#  'individuellement': [0, 0, 0],
#  'collectivement': [0, 0, 0],
#  'rejoindre': [0, 0, 0],
#  'groupe': [0, 0, 0],
#  'c’est': [0, 0, 0],
#  'aussi': [0, 0, 0],
#  'intégrer': [0, 0, 0],
#  'projet': [0, 0, 0],
#  'collectif': [0, 0, 0],
#  'où': [0, 0, 0],
#  'œuvrons': [0, 0, 0],
#  'renforcer': [0, 0, 0],
#  'notre': [0, 0, 0],
#  'ancrage': [0, 0, 0],
#  'local': [0, 0, 0],
#  'service': [0, 0, 0],
#  'du': [0, 0, 0],
#  'développement': [0, 0, 0],
#  'territoire': [0, 0, 0],
#  'croyons': [0, 0, 0],
#  'possibilité': [0, 0, 0],
#  'changer': [0, 0, 0],
#  'trajectoires': [0, 0, 0],
#  'sortir': [0, 0, 0],
#  'déterminismes': [0, 0, 0],
#  'sociaux': [0, 0, 0],
#  'économiques': [0, 0, 0],
#  'campus': [0, 0, 0],
#  'rassemble': [0, 0, 0],
#  'salariés': [0, 0, 0],
#  'sportifs': [0, 0, 0],
#  'niveau': [0, 0, 0],
#  'éducateurs': [0, 0, 0],
#  'chacun': [0, 0, 0],
#  'apprenant': [0, 0, 0],
#  'autres': [0, 0, 0],
#  'pour': [0, 0, 0],
#  'développer': [0, 0, 0],
#  'lui': [0, 0, 0],
#  'même': [0, 0, 0],
#  'impacter': [0, 0, 0],
#  'positivement': [0, 0, 0],
#  'concrétisons': [0, 0, 0],
#  'engagements': [0, 0, 0],
#  'devenant': [0, 0, 0],
#  'mission': [0, 0, 0],
#  'avec': [0, 0, 0],
#  'objectif': [0, 0, 0],
#  'ensemble': [0, 0, 0],
#  'provoquer': [0, 0, 0],
#  'les': [0, 0, 0],
#  'possibles': [0, 0, 0],
#  'poste': [0, 0, 0],
#  'pourquoi': [0, 0, 0],
#  'recrutons': [0, 0, 0],
#  'univers': [0, 0, 0],
#  'terrain': [0, 0, 0],
#  'jeu': [0, 0, 0],
#  'magique': [0, 0, 0],
#  'termes': [0, 0, 0],
#  'data': [0, 0, 0],
#  'données': [0, 0, 0],
#  'clients': [0, 0, 0],
#  'marketing': [0, 0, 0],
#  'fournisseurs': [0, 0, 0],
#  'navigation': [0, 0, 0],
#  'crm': [0, 0, 0],
#  'client': [0, 0, 0],
#  'activité': [0, 0, 0],
#  'génère': [0, 0, 0],
#  'important': [0, 0, 0],
#  'volume': [0, 0, 0],
#  'to': [0, 0, 0],
#  'dont': [0, 0, 0],
#  'analyse': [0, 0, 0],
#  'a': [0, 0, 0],
#  'impact': [0, 0, 0],
#  'direct': [0, 0, 0],
#  'expérience': [0, 0, 0],
#  'utilisateur': [0, 0, 0],
#  'conversion': [0, 0, 0],
#  'relations': [0, 0, 0],
#  'montons': [0, 0, 0],
#  'une': [0, 0, 0],
#  'nouvelle': [0, 0, 0],
#  'organisation': [0, 0, 0],
#  'ouvrons': [0, 0, 0],
#  'plusieurs': [0, 0, 0],
#  'postes': [0, 0, 0],
#  'clés': [0, 0, 0],
#  'écrire': [0, 0, 0],
#  'page': [0, 0, 0],
#  'tant': [0, 0, 0],
#  'que': [0, 0, 0],
#  'analyst': [0, 0, 0],
#  'vous': [0, 0, 0],
#  'serez': [0, 0, 0],
#  'charge': [0, 0, 0],
#  'identification': [0, 0, 0],
#  'leviers': [0, 0, 0],
#  'croissance': [0, 0, 0],
#  'rentabilité': [0, 0, 0],
#  'accompagnant': [0, 0, 0],
#  'prise': [0, 0, 0],
#  'décision': [0, 0, 0],
#  'différents': [0, 0, 0],
#  'départements': [0, 0, 0],
#  'produit': [0, 0, 0],
#  'achats': [0, 0, 0],
#  'sales': [0, 0, 0],
#  'transport': [0, 0, 0],
#  'finance': [0, 0, 0],
#  'amené': [0, 0, 0],
#  'maîtriser': [0, 0, 0],
#  'tout': [0, 0, 0],
#  'traitement': [0, 0, 0],
#  'donnée': [0, 0, 0],
#  'sera': [0, 0, 0],
#  'indispensable': [0, 0, 0],
#  'tracking': [0, 0, 0],
#  'adapté': [0, 0, 0],
#  'collecte': [0, 0, 0],
#  'fiable': [0, 0, 0],
#  'indicateurs': [0, 0, 0],
#  'pertinents': [0, 0, 0],
#  'modèle': [0, 0, 0],
#  'performant': [0, 0, 0],
#  'visualisations': [0, 0, 0],
#  'adaptées': [0, 0, 0],
#  'analyses': [0, 0, 0],
#  'b': [0, 0, 0],
#  'tests': [0, 0, 0],
#  'concluants': [0, 0, 0],
#  'missions': [0, 0, 0],
#  'monitorer': [0, 0, 0],
#  'performance': [0, 0, 0],
#  'ventes': [0, 0, 0],
#  'campagnes': [0, 0, 0],
#  'analyser': [0, 0, 0],
#  'plus': [0, 0, 0],
#  'demandés': [0, 0, 0],
#  'par': [0, 0, 0],
#  'visiteurs': [0, 0, 0],
#  'identifier': [0, 0, 0],
#  'destinations': [0, 0, 0],
#  'tendance': [0, 0, 0],
#  'alerter': [0, 0, 0],
#  'business': [0, 0, 0],
#  'cas': [0, 0, 0],
#  'comportement': [0, 0, 0],
#  'inattendu': [0, 0, 0],
#  'source': [0, 0, 0],
#  'problème': [0, 0, 0],
#  'recommander': [0, 0, 0],
#  'solution': [0, 0, 0],
#  'définir': [0, 0, 0],
#  'l’objectif': [0, 0, 0],
#  'l’a': [0, 0, 0],
#  'test': [0, 0, 0],
#  'périmètre': [0, 0, 0],
#  'permettant': [0, 0, 0],
#  'd’obtenir': [0, 0, 0],
#  'résultats': [0, 0, 0],
#  'rapides': [0, 0, 0],
#  'fiables': [0, 0, 0],
#  'limitant': [0, 0, 0],
#  'risques': [0, 0, 0],
#  'kpis': [0, 0, 0],
#  'suivre': [0, 0, 0],
#  'mesurer': [0, 0, 0],
#  'efficacement': [0, 0, 0],
#  'impacts': [0, 0, 0],
#  'potentiels': [0, 0, 0],
#  'réaliser': [0, 0, 0],
#  'basées': [0, 0, 0],
#  'significativité': [0, 0, 0],
#  'recommandations': [0, 0, 0],
#  'd': [0, 0, 0],
#  'actions': [0, 0, 0],
#  'ad': [0, 0, 0],
#  'hoc': [0, 0, 0],
#  'exploratoires': [0, 0, 0],
#  'améliorer': [0, 0, 0],
#  'compréhension': [0, 0, 0],
#  'd’un': [0, 0, 0],
#  'domaine': [0, 0, 0],
#  'd’une': [0, 0, 0],
#  'situation': [0, 0, 0],
#  'opportunités': [0, 0, 0],
#  'croissances': [0, 0, 0],
#  'traduire': [0, 0, 0],
#  'plan': [0, 0, 0],
#  'd’actions': [0, 0, 0],
#  'problématiques': [0, 0, 0],
#  'non': [0, 0, 0],
#  'maîtrisées': [0, 0, 0],
#  'date': [0, 0, 0],
#  'parler': [0, 0, 0],
#  'y': [0, 0, 0],
#  'répondre': [0, 0, 0],
#  'environnement': [0, 0, 0],
#  'technique': [0, 0, 0],
#  'tableau': [0, 0, 0],
#  'dataiku': [0, 0, 0],
#  'dss': [0, 0, 0],
#  'bigquery': [0, 0, 0],
#  'elasticsearch': [0, 0, 0],
#  'etl': [0, 0, 0],
#  'interne': [0, 0, 0],
#  'apache': [0, 0, 0],
#  'spark': [0, 0, 0],
#  'on': [0, 0, 0],
#  'yarn': [0, 0, 0],
#  'google': [0, 0, 0],
#  'cloud': [0, 0, 0],
#  'storage': [0, 0, 0],
#  'dataproc': [0, 0, 0],
#  'pub': [0, 0, 0],
#  'sub': [0, 0, 0],
#  'python': [0, 0, 0],
#  'scala': [0, 0, 0],
#  'docker': [0, 0, 0],
#  'github': [0, 0, 0],
#  'gitlabqualificationsformation': [0, 0, 0],
#  'supérieure': [0, 0, 0],
#  'bac': [0, 0, 0],
#  'école': [0, 0, 0],
#  'd’ingénieur': [0, 0, 0],
#  'ou': [0, 0, 0],
#  'spécialisation': [0, 0, 0],
#  'statistiques': [0, 0, 0],
#  'avez': [0, 0, 0],
#  'minimum': [0, 0, 0],
#  'ans': [0, 0, 0],
#  'd’expérience': [0, 0, 0],
#  'dans': [0, 0, 0],
#  'l’analyse': [0, 0, 0],
#  'digital': [0, 0, 0],
#  'êtes': [0, 0, 0],
#  'reconnu': [0, 0, 0],
#  'votre': [0, 0, 0],
#  'rigueur': [0, 0, 0],
#  'excellent': [0, 0, 0],
#  'sens': [0, 0, 0],
#  'bon': [0, 0, 0],
#  'relationnel': [0, 0, 0],
#  'aimez': [0, 0, 0],
#  'travailler': [0, 0, 0],
#  'équipe': [0, 0, 0],
#  'notions': [0, 0, 0],
#  'sql': [0, 0, 0],
#  'maîtrisez': [0, 0, 0],
#  'outil': [0, 0, 0],
#  'bi': [0, 0, 0],
#  'marché': [0, 0, 0],
#  'forte': [0, 0, 0],
#  'fort': [0, 0, 0],
#  'esprit': [0, 0, 0],
#  'analytique': [0, 0, 0],
#  'bases': [0, 0, 0],
#  'solides': [0, 0, 0],
#  'statistique': [0, 0, 0],
#  'savez': [0, 0, 0],
#  'communiquer': [0, 0, 0],
#  'clairement': [0, 0, 0],
#  'vos': [0, 0, 0],
#  'd’analyses': [0, 0, 0],
#  'synthèse': [0, 0, 0],
#  'l’intérêt': [0, 0, 0],
#  'nouveaux': [0, 0, 0],
#  'langages': [0, 0, 0],
#  'tels': [0, 0, 0],
#  'r': [0, 0, 0],
#  'proposer': [0, 0, 0],
#  'nouvelles': [0, 0, 0],
#  'idées': [0, 0, 0],
#  'avancer': [0, 0, 0],
#  'informations': [0, 0, 0],
#  'supplémentaires': [0, 0, 0],
#  'journey': [0, 0, 0],
#  'grandir': [0, 0, 0],
#  'équipes': [0, 0, 0],
#  'dynamique': [0, 0, 0],
#  'exposé': [0, 0, 0],
#  'l’international': [0, 0, 0],
#  'être': [0, 0, 0],
#  'entièrement': [0, 0, 0],
#  'impliqué': [0, 0, 0],
#  'l’aventure': [0, 0, 0],
#  'devenir': [0, 0, 0],
#  'acteur': [0, 0, 0],
#  'réussite': [0, 0, 0],
#  'participation': [0, 0, 0],
#  'vivre': [0, 0, 0],
#  'sud': [0, 0, 0],
#  'cadre': [0, 0, 0],
#  'naturel': [0, 0, 0],
#  'économique': [0, 0, 0],
#  'culturel': [0, 0, 0],
#  'exceptionnel': [0, 0, 0],
#  's’impliquer': [0, 0, 0],
#  'projets': [0, 0, 0],
#  'sociétaux': [0, 0, 0],
#  'orientés': [0, 0, 0],
#  'éducation': [0, 0, 0],
#  'sport': [0, 0, 0],
#  'ecole': [0, 0, 0],
#  'xv': [0, 0, 0],
#  'vp': [0, 0, 0],
#  'green': [0, 0, 0],
#  'accompagner': [0, 0, 0],
#  'start': [0, 0, 0],
#  'up': [0, 0, 0],
#  'accélérateur': [0, 0, 0],
#  'tremplins': [0, 0, 0],
#  'innovation': [0, 0, 0],
#  'tourisme': [0, 0, 0],
#  'bénéficier': [0, 0, 0],
#  'tarifs': [0, 0, 0],
#  'encore': [0, 0, 0],
#  'avantageux': [0, 0, 0],
#  'sites': [0, 0, 0],
#  'profiter': [0, 0, 0],
#  'famille': [0, 0, 0],
#  'amis': [0, 0, 0],
#  'participer': [0, 0, 0],
#  'collègues': [0, 0, 0],
#  'aux': [0, 0, 0],
#  'cours': [0, 0, 0],
#  'offerts': [0, 0, 0],
#  'matchs': [0, 0, 0],
#  'rugby': [0, 0, 0],
#  'provence': [0, 0, 0],
#  'enfin': [0, 0, 0],
#  'nombreux': [0, 0, 0],
#  'évènements': [0, 0, 0],
#  'internes': [0, 0, 0],
#  'company': [0, 0, 0],
#  'breaks': [0, 0, 0],
#  'mensuels': [0, 0, 0],
#  'convention': [0, 0, 0],
#  'annuelle': [0, 0, 0],
#  'etc': [0, 0, 0],
#  'rythment': [0, 0, 0],
#  'vie': [0, 0, 0],
#  'euro': [0, 0, 0],
#  'information': [0, 0, 0],
#  'filiale': [0, 0, 0],
#  'technologique': [0, 0, 0],
#  'crédit': [0, 0, 0],
#  'mutuel': [0, 0, 0],
#  'alliance': [0, 0, 0],
#  'fédérale': [0, 0, 0],
#  'conçoit': [0, 0, 0],
#  'réalise': [0, 0, 0],
#  'maintient': [0, 0, 0],
#  'exploite': [0, 0, 0],
#  'système': [0, 0, 0],
#  'd’information': [0, 0, 0],
#  'commun': [0, 0, 0],
#  'utilisé': [0, 0, 0],
#  'activités': [0, 0, 0],
#  'production': [0, 0, 0],
#  'informatique': [0, 0, 0],
#  'national': [0, 0, 0],
#  'international': [0, 0, 0],
#  'assurées': [0, 0, 0],
#  'environ': [0, 0, 0],
#  'répartis': [0, 0, 0],
#  'géographiques': [0, 0, 0],
#  'strasbourg': [0, 0, 0],
#  'nancy': [0, 0, 0],
#  'dijon': [0, 0, 0],
#  'orléans': [0, 0, 0],
#  'lyon': [0, 0, 0],
#  'lille': [0, 0, 0],
#  'cergy': [0, 0, 0],
#  'val': [0, 0, 0],
#  'fontenay': [0, 0, 0],
#  'paris': [0, 0, 0],
#  'nantes': [0, 0, 0],
#  'l’arrivée': [0, 0, 0],
#  'maturité': [0, 0, 0],
#  'solutions': [0, 0, 0],
#  'informatiques': [0, 0, 0],
#  'automatique': [0, 0, 0],
#  'langage': [0, 0, 0],
#  'ainsi': [0, 0, 0],
#  'qu’un': [0, 0, 0],
#  'apprentissage': [0, 0, 0],
#  'l’exemple': [0, 0, 0],
#  'ouvert': [0, 0, 0],
#  'perspectives': [0, 0, 0],
#  'mieux': [0, 0, 0],
#  'assister': [0, 0, 0],
#  'servir': [0, 0, 0],
#  'leurs': [0, 0, 0],
#  'donc': [0, 0, 0],
#  'décidé': [0, 0, 0],
#  'd’investir': [0, 0, 0],
#  'fortement': [0, 0, 0],
#  'l’informatique': [0, 0, 0],
#  'cognitive': [0, 0, 0],
#  'avons': [0, 0, 0],
#  'été': [0, 0, 0],
#  'première': [0, 0, 0],
#  'mettre': [0, 0, 0],
#  'œuvre': [0, 0, 0],
#  'technologie': [0, 0, 0],
#  'ibm': [0, 0, 0],
#  'watson': [0, 0, 0],
#  'dites': [0, 0, 0],
#  'cognitives': [0, 0, 0],
#  'déployées': [0, 0, 0],
#  'assistants': [0, 0, 0],
#  'virtuels': [0, 0, 0],
#  'chatbot': [0, 0, 0],
#  'analyseurs': [0, 0, 0],
#  'd’emails': [0, 0, 0],
#  'assistant': [0, 0, 0],
#  'vocal': [0, 0, 0],
#  'téléphonique': [0, 0, 0],
#  'sein': [0, 0, 0],
#  'secteur': [0, 0, 0],
#  'innovant': [0, 0, 0],
#  'rejoignez': [0, 0, 0],
#  'l’équipe': [0, 0, 0],
#  'exploitation': [0, 0, 0],
#  'architectures': [0, 0, 0],
#  'l’architecture': [0, 0, 0],
#  'applicative': [0, 0, 0],
#  'créer': [0, 0, 0],
#  'outils': [0, 0, 0],
#  'récoltées': [0, 0, 0],
#  'd’enrichir': [0, 0, 0],
#  'processus': [0, 0, 0],
#  'métiers': [0, 0, 0],
#  'selon': [0, 0, 0],
#  'ces': [0, 0, 0],
#  'composants': [0, 0, 0],
#  'déclinent': [0, 0, 0],
#  'technologies': [0, 0, 0],
#  'c': [0, 0, 0],
#  'serveur': [0, 0, 0],
#  'nosql': [0, 0, 0],
#  'kibana': [0, 0, 0],
#  'kafka…': [0, 0, 0],
#  'intégré': [0, 0, 0],
#  'dizaine': [0, 0, 0],
#  'personnes': [0, 0, 0],
#  'seront': [0, 0, 0],
#  'relation': [0, 0, 0],
#  'gestion': [0, 0, 0],
#  'précisément': [0, 0, 0],
#  'concevoir': [0, 0, 0],
#  'rédiger': [0, 0, 0],
#  'spécifications': [0, 0, 0],
#  'fonctionnelles': [0, 0, 0],
#  'applicatives': [0, 0, 0],
#  'techniques': [0, 0, 0],
#  'applications': [0, 0, 0],
#  'intranet': [0, 0, 0],
#  'd’exploration': [0, 0, 0],
#  'restitution': [0, 0, 0],
#  'modéliser': [0, 0, 0],
#  'décisionnel': [0, 0, 0],
#  'dashboard': [0, 0, 0],
#  'apporter': [0, 0, 0],
#  'support': [0, 0, 0],
#  'organiser': [0, 0, 0],
#  'recette': [0, 0, 0],
#  'gérer': [0, 0, 0],
#  'demandes': [0, 0, 0],
#  'd’évolution': [0, 0, 0],
#  'mode': [0, 0, 0],
#  'respect': [0, 0, 0],
#  'management': [0, 0, 0],
#  'qualité': [0, 0, 0],
#  'allez': [0, 0, 0],
#  'chez': [0, 0, 0],
#  'noustélétravail': [0, 0, 0],
#  'jours': [0, 0, 0],
#  'semaine': [0, 0, 0],
#  'rémunération': [0, 0, 0],
#  'fixe': [0, 0, 0],
#  'versée': [0, 0, 0],
#  'mois': [0, 0, 0],
#  'rtt': [0, 0, 0],
#  'intéressement': [0, 0, 0],
#  'abondement': [0, 0, 0],
#  'épargne': [0, 0, 0],
#  'perco': [0, 0, 0],
#  'contrat': [0, 0, 0],
#  'santé': [0, 0, 0],
#  'prévoyance': [0, 0, 0],
#  'retraite': [0, 0, 0],
#  'supplémentaire': [0, 0, 0],
#  'l’employeur': [0, 0, 0],
#  'conditions': [0, 0, 0],
#  'bancaires': [0, 0, 0],
#  'assurances': [0, 0, 0],
#  'préférentielles': [0, 0, 0],
#  'politique': [0, 0, 0],
#  'parentale': [0, 0, 0],
#  'avantageuse': [0, 0, 0],
#  'allons': [0, 0, 0],
#  'aimer': [0, 0, 0],
#  'issu': [0, 0, 0],
#  'formation': [0, 0, 0],
#  'maitrisez': [0, 0, 0],
#  'base': [0, 0, 0],
#  'orientée': [0, 0, 0],
#  'programmation': [0, 0, 0],
#  'objet': [0, 0, 0],
#  'type': [0, 0, 0],
#  'plaira': [0, 0, 0],
#  'alors': [0, 0, 0],
#  'bien': [0, 0, 0],
#  'évidemment': [0, 0, 0],
#  'préférera': [0, 0, 0],
#  'curieux': [0, 0, 0],
#  'innovations': [0, 0, 0],
#  'technologiques': [0, 0, 0],
#  'prêt': [0, 0, 0],
#  'relever': [0, 0, 0],
#  'défis': [0, 0, 0],
#  'faisant': [0, 0, 0],
#  'preuve': [0, 0, 0],
#  'd’écoute': [0, 0, 0],
#  'car': [0, 0, 0],
#  'permettra': [0, 0, 0],
#  'mener': [0, 0, 0],
#  'également': [0, 0, 0],
#  'capacités': [0, 0, 0],
#  'd’analyse': [0, 0, 0],
#  'souci': [0, 0, 0],
#  'normes': [0, 0, 0],
#  'standards': [0, 0, 0],
#  'appréciez': [0, 0, 0],
#  'apprendre': [0, 0, 0],
#  'mais': [0, 0, 0],
#  'collaboration': [0, 0, 0],
#  'cette': [0, 0, 0],
#  'offre': [0, 0, 0],
#  'faite': [0, 0, 0],
#  'complémentaires': [0, 0, 0],
#  'basé': [0, 0, 0],
#  'pourvoir': [0, 0, 0],
#  'cdi': [0, 0, 0],
#  'dès': [0, 0, 0],
#  'possible': [0, 0, 0],
#  'faisons': [0, 0, 0],
#  'connaissance': [0, 0, 0],
#  'régie': [0, 0, 0],
#  'plurimédia': [0, 0, 0],
#  'tf': [0, 0, 0],
#  'publicité': [0, 0, 0],
#  'commercialise': [0, 0, 0],
#  'espaces': [0, 0, 0],
#  'publicitaires': [0, 0, 0],
#  'supports': [0, 0, 0],
#  'médias': [0, 0, 0],
#  'télévision': [0, 0, 0],
#  'écrans': [0, 0, 0],
#  'classique': [0, 0, 0],
#  'dispositifs': [0, 0, 0],
#  'parrainage': [0, 0, 0],
#  'chaînes': [0, 0, 0],
#  'tmc': [0, 0, 0],
#  'tfx': [0, 0, 0],
#  'séries': [0, 0, 0],
#  'films': [0, 0, 0],
#  'lci': [0, 0, 0],
#  'tv': [0, 0, 0],
#  'breizh': [0, 0, 0],
#  'ushuaïa': [0, 0, 0],
#  'histoire': [0, 0, 0],
#  'depuis': [0, 0, 0],
#  'peu': [0, 0, 0],
#  'chaîne': [0, 0, 0],
#  'réunionnaise': [0, 0, 0],
#  'antenne': [0, 0, 0],
#  'réunion': [0, 0, 0],
#  'radios': [0, 0, 0],
#  'indés': [0, 0, 0],
#  'm': [0, 0, 0],
#  'radio': [0, 0, 0],
#  'outre': [0, 0, 0],
#  'mer': [0, 0, 0],
#  'autour': [0, 0, 0],
#  'déclinaisons': [0, 0, 0],
#  'digitales': [0, 0, 0],
#  'commercialisées': [0, 0, 0],
#  'assets': [0, 0, 0],
#  'digitaux': [0, 0, 0],
#  'mytf': [0, 0, 0],
#  'poursuivant': [0, 0, 0],
#  'déploiement': [0, 0, 0],
#  'stratégie': [0, 0, 0],
#  'digitale': [0, 0, 0],
#  'pc': [0, 0, 0],
#  'mobile': [0, 0, 0],
#  'tablette': [0, 0, 0],
#  'travers': [0, 0, 0],
#  'diversité': [0, 0, 0],
#  'attractivité': [0, 0, 0],
#  'propose': [0, 0, 0],
#  'ses': [0, 0, 0],
#  'annonceurs': [0, 0, 0],
#  'modes': [0, 0, 0],
#  'expression': [0, 0, 0],
#  'différenciés': [0, 0, 0],
#  'adaptés': [0, 0, 0],
#  'besoins': [0, 0, 0],
#  'revenu': [0, 0, 0],
#  'piloter': [0, 0, 0],
#  'inventaires': [0, 0, 0],
#  'offres': [0, 0, 0],
#  'adserving': [0, 0, 0],
#  'afin': [0, 0, 0],
#  'opérer': [0, 0, 0],
#  'appliquer': [0, 0, 0],
#  'analyste': [0, 0, 0],
#  'aura': [0, 0, 0],
#  'suivantes': [0, 0, 0],
#  'suivi': [0, 0, 0],
#  'audiences': [0, 0, 0],
#  'reporting': [0, 0, 0],
#  'replay': [0, 0, 0],
#  'segmentée…': [0, 0, 0],
#  'vidéos': [0, 0, 0],
#  'vues': [0, 0, 0],
#  'remplissage': [0, 0, 0],
#  'impressions': [0, 0, 0],
#  'maintenance': [0, 0, 0],
#  'adserver': [0, 0, 0],
#  'freewheel': [0, 0, 0],
#  'assurer': [0, 0, 0],
#  'correcte': [0, 0, 0],
#  'diffusion': [0, 0, 0],
#  'mise': [0, 0, 0],
#  'jour': [0, 0, 0],
#  'commerciaux': [0, 0, 0],
#  'avant': [0, 0, 0],
#  'disponible': [0, 0, 0],
#  'réservation': [0, 0, 0],
#  'ops': [0, 0, 0],
#  'sponsoring': [0, 0, 0],
#  'adserve': [0, 0, 0],
#  'localisation': [0, 0, 0],
#  'boulogne': [0, 0, 0],
#  'billancourt': [0, 0, 0],
#  'atouts': [0, 0, 0],
#  'différencevous': [0, 0, 0],
#  'préparez': [0, 0, 0],
#  'economie': [0, 0, 0],
#  'revenue': [0, 0, 0],
#  'commerce': [0, 0, 0],
#  'université': [0, 0, 0],
#  'équivalent': [0, 0, 0],
#  'maitriser': [0, 0, 0],
#  'excellente': [0, 0, 0],
#  'maîtrise': [0, 0, 0],
#  'excel': [0, 0, 0],
#  'software': [0, 0, 0],
#  'objects': [0, 0, 0],
#  'aise': [0, 0, 0],
#  'adservers': [0, 0, 0],
#  'dfp': [0, 0, 0],
#  'faites': [0, 0, 0],
#  'raisonnement': [0, 0, 0],
#  'structuré': [0, 0, 0],
#  'réelle': [0, 0, 0],
#  'capacité': [0, 0, 0],
#  'transversalité': [0, 0, 0],
#  'fonctionnement': [0, 0, 0],
#  'aisance': [0, 0, 0],
#  'relationnelle': [0, 0, 0],
#  'adaptation': [0, 0, 0],
#  'travail': [0, 0, 0],
#  'font': [0, 0, 0],
#  'partie': [0, 0, 0],
#  'mène': [0, 0, 0],
#  'engagée': [0, 0, 0],
#  'garantir': [0, 0, 0],
#  'équité': [0, 0, 0],
#  'ouverts': [0, 0, 0],
#  'handicap': [0, 0, 0],
#  'région': [0, 0, 0],
#  'île': [0, 0, 0],
#  'recherche': [0, 0, 0],
#  'responsable': [0, 0, 0],
#  'professionnelle': [0, 0, 0],
#  'ptn': [0, 0, 0],
#  'pôle': [0, 0, 0],
#  'transformation': [0, 0, 0],
#  'numérique': [0, 0, 0],
#  'direction': [0, 0, 0],
#  'sous': [0, 0, 0],
#  'responsabilité': [0, 0, 0],
#  'pilote': [0, 0, 0],
#  'liés': [0, 0, 0],
#  'feuille': [0, 0, 0],
#  'route': [0, 0, 0],
#  'pfpa': [0, 0, 0],
#  'il': [0, 0, 0],
#  'assure': [0, 0, 0],
#  'appui': [0, 0, 0],
#  'documentation': [0, 0, 0],
#  'modélisation': [0, 0, 0],
#  'liée': [0, 0, 0],
#  'titre': [0, 0, 0],
#  'elle': [0, 0, 0],
#  'accompagne': [0, 0, 0],
#  'chefs': [0, 0, 0],
#  'leur': [0, 0, 0],
#  'apporte': [0, 0, 0],
#  'conseil': [0, 0, 0],
#  'expert': [0, 0, 0],
#  'ressources': [0, 0, 0],
#  'cohérence': [0, 0, 0],
#  'lignes': [0, 0, 0],
#  'directrices': [0, 0, 0],
#  'liées': [0, 0, 0],
#  'gouvernance': [0, 0, 0],
#  'compétence': [0, 0, 0],
#  'régionale': [0, 0, 0],
#  'carif': [0, 0, 0],
#  'recensement': [0, 0, 0],
#  'l’offre': [0, 0, 0],
#  'sa': [0, 0, 0],
#  'dimension': [0, 0, 0],
#  'chantiers': [0, 0, 0],
#  'applicatifs': [0, 0, 0],
#  'equiper': [0, 0, 0],
#  'métier': [0, 0, 0],
#  'cartographie': [0, 0, 0],
#  'l’identification': [0, 0, 0],
#  'sources': [0, 0, 0],
#  'référentiels': [0, 0, 0],
#  'maîtres': [0, 0, 0],
#  'appuyer': [0, 0, 0],
#  'formalisation': [0, 0, 0],
#  'prioritaires': [0, 0, 0],
#  'l’outillage': [0, 0, 0],
#  'd’assurer': [0, 0, 0],
#  'l’intégrité': [0, 0, 0],
#  'sécurité': [0, 0, 0],
#  'conduire': [0, 0, 0],
#  'renforcement': [0, 0, 0],
#  'place': [0, 0, 0],
#  'décisionnels': [0, 0, 0],
#  'datawarehouses': [0, 0, 0],
#  'datamarts': [0, 0, 0],
#  'tableaux': [0, 0, 0],
#  'bord': [0, 0, 0],
#  'lien': [0, 0, 0],
#  'profilcompétences': [0, 0, 0],
#  'requises': [0, 0, 0],
#  'enjeux': [0, 0, 0],
#  'cycle': [0, 0, 0],
#  'conceptuelle': [0, 0, 0],
#  'n’est': [0, 0, 0],
#  'requise': [0, 0, 0],
#  'savoir': [0, 0, 0],
#  'méthodologiques': [0, 0, 0],
#  'matière': [0, 0, 0],
#  'numériques': [0, 0, 0],
#  'utilisateurs': [0, 0, 0],
#  'poser': [0, 0, 0],
#  'rapidement': [0, 0, 0],
#  'diagnostic': [0, 0, 0],
#  'fonctionnels': [0, 0, 0],
#  'limites': [0, 0, 0],
#  'avérée': [0, 0, 0],
#  'aptitude': [0, 0, 0],
#  'stratégique': [0, 0, 0],
#  'force': [0, 0, 0],
#  'proposition': [0, 0, 0],
#  'd’initiative': [0, 0, 0],
#  'goût': [0, 0, 0],
#  'l’action': [0, 0, 0],
#  'l’innovation': [0, 0, 0],
#  'l’usager': [0, 0, 0],
#  'public': [0, 0, 0],
#  'pédagogie': [0, 0, 0],
#  'l’explication': [0, 0, 0],
#  'spécialistes': [0, 0, 0],
#  'pro': [0, 0, 0],
#  'autonomie': [0, 0, 0],
#  'adaptabilité': [0, 0, 0],
#  'dynamisme': [0, 0, 0],
#  'réactivité': [0, 0, 0],
#  'sauf': [0, 0, 0],
#  'mention': [0, 0, 0],
#  'durée': [0, 0, 0],
#  'déterminée': [0, 0, 0],
#  'cdd': [0, 0, 0],
#  'cet': [0, 0, 0],
#  'emploi': [0, 0, 0],
#  'priorité': [0, 0, 0],
#  'agents': [0, 0, 0],
#  'titulaires': [0, 0, 0],
#  'fonction': [0, 0, 0],
#  'publique': [0, 0, 0],
#  'voie': [0, 0, 0],
#  'mutation': [0, 0, 0],
#  'détachement': [0, 0, 0],
#  'inscrits': [0, 0, 0],
#  'liste': [0, 0, 0],
#  'qu’aux': [0, 0, 0],
#  'contractuels': [0, 0, 0],
#  'décret': [0, 0, 0],
#  'n°': [0, 0, 0],
#  'février': [0, 0, 0],
#  'pris': [0, 0, 0],
#  'application': [0, 0, 0],
#  'article': [0, 0, 0],
#  'loi': [0, 0, 0],
#  'janvier': [0, 0, 0],
#  'modifiée': [0, 0, 0],
#  'portant': [0, 0, 0],
#  'dispositions': [0, 0, 0],
#  'statutaires': [0, 0, 0],
#  'relatives': [0, 0, 0],
#  'territoriale': [0, 0, 0],
#  'relatif': [0, 0, 0],
#  'construisons': [0, 0, 0],
#  'lieu': [0, 0, 0],
#  'demain': [0, 0, 0],
#  'installée': [0, 0, 0],
#  'l’éco': [0, 0, 0],
#  'quartier': [0, 0, 0],
#  'docks': [0, 0, 0],
#  'saint': [0, 0, 0],
#  'ouen': [0, 0, 0],
#  'bâtiment': [0, 0, 0],
#  'hqe': [0, 0, 0],
#  'télétravail': [0, 0, 0],
#  'salle': [0, 0, 0],
#  'services…': [0, 0, 0],
#  'réinventé': [0, 0, 0],
#  'confiance': [0, 0, 0],
#  'humaines': [0, 0, 0],
#  'active': [0, 0, 0],
#  'ile': [0, 0, 0],
#  'lutte': [0, 0, 0],
#  'contre': [0, 0, 0],
#  'toutes': [0, 0, 0],
#  'formes': [0, 0, 0],
#  'discriminations': [0, 0, 0],
#  'vise': [0, 0, 0],
#  'diversifier': [0, 0, 0],
#  'candidatures': [0, 0, 0],
#  'reconnaît': [0, 0, 0],
#  'talents': [0, 0, 0],
#  'handi': [0, 0, 0],
#  'accessible': [0, 0, 0],
#  'régional': [0, 0, 0],
#  'mondial': [0, 0, 0],
#  'relay': [0, 0, 0],
#  'qu': [0, 0, 0],
#  'simple': [0, 0, 0],
#  'colis': [0, 0, 0],
#  'offrons': [0, 0, 0],
#  'expédition': [0, 0, 0],
#  'livraison': [0, 0, 0],
#  'rapide': [0, 0, 0],
#  'vertueux': [0, 0, 0],
#  'réseau': [0, 0, 0],
#  'points': [0, 0, 0],
#  'relais': [0, 0, 0],
#  'lockers': [0, 0, 0],
#  'créateur': [0, 0, 0],
#  'liens': [0, 0, 0],
#  'entre': [0, 0, 0],
#  'commerçants': [0, 0, 0],
#  'consommateurs': [0, 0, 0],
#  'précurseurs': [0, 0, 0],
#  'tendances': [0, 0, 0],
#  'écoute': [0, 0, 0],
#  'portés': [0, 0, 0],
#  'contexte': [0, 0, 0],
#  'constant': [0, 0, 0],
#  'hors': [0, 0, 0],
#  'domicile': [0, 0, 0],
#  'ambitionnons': [0, 0, 0],
#  'étendre': [0, 0, 0],
#  'préférence': [0, 0, 0],
#  'challenge': [0, 0, 0],
#  'basés': [0, 0, 0],
#  'relèvent': [0, 0, 0],
#  'passion': [0, 0, 0],
#  'accomplissement': [0, 0, 0],
#  'collaboratifs': [0, 0, 0],
#  'ambiance': [0, 0, 0],
#  'pleine': [0, 0, 0],
#  'pep': [0, 0, 0],
#  'recherchons': [0, 0, 0],
#  'futur': [0, 0, 0],
#  'relayeuses': [0, 0, 0],
#  'relayeurs': [0, 0, 0],
#  'prendre': [0, 0, 0],
#  'part': [0, 0, 0],
#  'suite': [0, 0, 0],
#  'côtés': [0, 0, 0],
#  'si': [0, 0, 0],
#  'comme': [0, 0, 0],
#  'convaincu': [0, 0, 0],
#  'n': [0, 0, 0],
#  'attendez': [0, 0, 0],
#  'découvrez': [0, 0, 0],
#  'prochain': [0, 0, 0],
#  'h': [0, 0, 0],
#  'f': [0, 0, 0],
#  'excellence': [0, 0, 0],
#  'opérationnelle': [0, 0, 0],
#  'évoluer': [0, 0, 0],
#  'process': [0, 0, 0],
#  'globale': [0, 0, 0],
#  'notamment': [0, 0, 0],
#  'celle': [0, 0, 0],
#  'relative': [0, 0, 0],
#  'amélioration': [0, 0, 0],
#  'efficience': [0, 0, 0],
#  'opérations': [0, 0, 0],
#  'cœur': [0, 0, 0],
#  'directions': [0, 0, 0],
#  'opération': [0, 0, 0],
#  'industrielle': [0, 0, 0],
#  'soutenez': [0, 0, 0],
#  'activement': [0, 0, 0],
#  'directeurs': [0, 0, 0],
#  'industriel': [0, 0, 0],
#  'initiatives': [0, 0, 0],
#  'stratégiques': [0, 0, 0],
#  'visant': [0, 0, 0],
#  'continue': [0, 0, 0],
#  'opérationnels': [0, 0, 0],
#  ...}

# %%
for i in range(nt):   
    for mot in description[i].split():
        motex[mot][i] += 1

# %%
motex
# Out:
# {'description': [160, 114, 206],
#  'de': [13556, 8280, 10562],
#  'l': [2699, 1656, 2207],
#  'entreprise': [394, 208, 300],
#  'aventure': [69, 28, 52],
#  'entrepreneuriale': [5, 3, 3],
#  'lancée': [11, 1, 5],
#  'en': [3945, 2372, 2982],
#  'france': [369, 148, 194],
#  'voyage': [12, 6, 24],
#  'privé': [8, 5, 7],
#  'est': [1106, 691, 947],
#  'le': [2740, 1537, 2085],
#  'leader': [109, 55, 58],
#  'européen': [30, 13, 55],
#  'la': [5025, 2768, 3940],
#  'vente': [53, 23, 22],
#  'éphémère': [1, 1, 1],
#  'ligne': [39, 16, 12],
#  'ce': [503, 288, 344],
#  'qui': [629, 365, 537],
#  'nous': [1284, 731, 1317],
#  'anime': [12, 1, 5],
#  'faire': [302, 144, 237],
#  'voyager': [1, 2, 1],
#  'nos': [954, 581, 887],
#  'millions': [71, 51, 20],
#  'membres': [23, 23, 30],
#  'dénichant': [1, 1, 1],
#  'des': [5720, 3307, 4158],
#  'produits': [187, 101, 93],
#  'haut': [22, 16, 35],
#  'gamme': [37, 13, 8],
#  'au': [1526, 850, 1178],
#  'meilleur': [29, 21, 24],
#  'prix': [15, 11, 17],
#  'sommes': [172, 93, 190],
#  'présents': [21, 8, 11],
#  'sur': [1397, 873, 1352],
#  'neuf': [7, 6, 5],
#  'marchés': [56, 27, 26],
#  'et': [8584, 4791, 6716],
#  'ne': [92, 37, 53],
#  'comptons': [6, 4, 5],
#  'pas': [164, 66, 120],
#  's’arrêter': [1, 1, 1],
#  'là': [20, 27, 44],
#  'collaborateurs': [293, 174, 230],
#  'sont': [423, 205, 336],
#  'ambitieux': [21, 24, 35],
#  'se': [202, 116, 222],
#  'passionné': [30, 50, 41],
#  'e': [584, 355, 386],
#  's': [272, 150, 202],
#  'exigeant': [10, 4, 8],
#  'tous': [249, 124, 199],
#  'ont': [53, 40, 47],
#  'un': [2222, 1397, 1877],
#  'rôle': [126, 45, 63],
#  'à': [3764, 2119, 2805],
#  'jouer': [10, 3, 4],
#  'individuellement': [1, 2, 1],
#  'collectivement': [2, 1, 1],
#  'rejoindre': [202, 97, 182],
#  'groupe': [502, 347, 351],
#  'c’est': [88, 38, 81],
#  'aussi': [124, 99, 136],
#  'intégrer': [67, 47, 96],
#  'projet': [264, 145, 211],
#  'collectif': [15, 12, 6],
#  'où': [94, 66, 111],
#  'œuvrons': [2, 1, 2],
#  'renforcer': [27, 24, 30],
#  'notre': [747, 399, 657],
#  'ancrage': [2, 1, 3],
#  'local': [11, 8, 10],
#  'service': [226, 134, 135],
#  'du': [2045, 1326, 1540],
#  'développement': [357, 336, 449],
#  'territoire': [14, 17, 26],
#  'croyons': [5, 2, 6],
#  'possibilité': [45, 38, 69],
#  'changer': [9, 6, 4],
#  'trajectoires': [1, 1, 1],
#  'sortir': [4, 1, 2],
#  'déterminismes': [1, 1, 1],
#  'sociaux': [24, 8, 5],
#  'économiques': [8, 2, 3],
#  'campus': [7, 7, 2],
#  'rassemble': [7, 10, 2],
#  'salariés': [25, 18, 34],
#  'sportifs': [7, 2, 6],
#  'niveau': [318, 150, 161],
#  'éducateurs': [1, 1, 1],
#  'chacun': [59, 34, 77],
#  'apprenant': [2, 1, 1],
#  'autres': [125, 72, 84],
#  'pour': [2117, 1262, 1704],
#  'développer': [187, 184, 191],
#  'lui': [8, 16, 10],
#  'même': [55, 30, 35],
#  'impacter': [1, 1, 1],
#  'positivement': [6, 5, 6],
#  'concrétisons': [2, 1, 4],
#  'engagements': [19, 23, 17],
#  'devenant': [5, 2, 1],
#  'mission': [245, 179, 224],
#  'avec': [1371, 782, 1038],
#  'objectif': [76, 53, 55],
#  'ensemble': [167, 95, 112],
#  'provoquer': [1, 1, 1],
#  'les': [3991, 2058, 2969],
#  'possibles': [14, 9, 9],
#  'poste': [578, 309, 415],
#  'pourquoi': [68, 51, 51],
#  'recrutons': [30, 13, 35],
#  'univers': [26, 13, 17],
#  'terrain': [32, 10, 10],
#  'jeu': [22, 7, 5],
#  'magique': [1, 0, 1],
#  'termes': [30, 8, 22],
#  'data': [2053, 1401, 2376],
#  'données': [1643, 697, 1356],
#  'clients': [640, 304, 403],
#  'marketing': [347, 124, 44],
#  'fournisseurs': [16, 16, 7],
#  'navigation': [8, 8, 9],
#  'crm': [77, 36, 23],
#  'client': [306, 151, 200],
#  'activité': [140, 41, 77],
#  'génère': [3, 4, 1],
#  'important': [34, 7, 38],
#  'volume': [17, 9, 10],
#  'to': [196, 135, 113],
#  'dont': [80, 56, 71],
#  'analyse': [562, 237, 149],
#  'a': [456, 267, 311],
#  'impact': [67, 33, 43],
#  'direct': [26, 8, 11],
#  'expérience': [505, 303, 466],
#  'utilisateur': [22, 9, 8],
#  'conversion': [7, 5, 2],
#  'relations': [22, 10, 10],
#  'montons': [1, 0, 1],
#  'une': [1979, 1249, 1684],
#  'nouvelle': [49, 38, 43],
#  'organisation': [111, 53, 76],
#  'ouvrons': [2, 0, 1],
#  'plusieurs': [77, 70, 152],
#  'postes': [40, 17, 39],
#  'clés': [77, 20, 38],
#  'écrire': [5, 4, 21],
#  'page': [31, 12, 14],
#  'tant': [171, 113, 123],
#  'que': [771, 397, 727],
#  'analyst': [475, 6, 22],
#  'vous': [3069, 1883, 2418],
#  'serez': [156, 79, 92],
#  'charge': [201, 61, 80],
#  'identification': [37, 20, 20],
#  'leviers': [30, 13, 5],
#  'croissance': [119, 53, 75],
#  'rentabilité': [15, 9, 1],
#  'accompagnant': [8, 4, 6],
#  'prise': [143, 56, 65],
#  'décision': [90, 36, 21],
#  'différents': [204, 98, 108],
#  'départements': [21, 10, 3],
#  'produit': [102, 20, 38],
#  'achats': [39, 18, 1],
#  'sales': [42, 0, 6],
#  'transport': [72, 31, 38],
#  'finance': [95, 42, 94],
#  'amené': [72, 44, 30],
#  'maîtriser': [12, 10, 0],
#  'tout': [211, 117, 243],
#  'traitement': [131, 129, 158],
#  'donnée': [175, 78, 240],
#  'sera': [103, 75, 93],
#  'indispensable': [50, 35, 19],
#  'tracking': [20, 3, 0],
#  'adapté': [8, 9, 9],
#  'collecte': [54, 28, 56],
#  'fiable': [11, 3, 11],
#  'indicateurs': [157, 40, 11],
#  'pertinents': [28, 12, 5],
#  'modèle': [49, 59, 39],
#  'performant': [5, 6, 5],
#  'visualisations': [13, 5, 1],
#  'adaptées': [19, 20, 18],
#  'analyses': [298, 84, 35],
#  'b': [105, 20, 8],
#  'tests': [62, 29, 81],
#  'concluants': [1, 0, 0],
#  'missions': [464, 262, 256],
#  'monitorer': [7, 2, 11],
#  'performance': [238, 87, 79],
#  'ventes': [38, 6, 10],
#  'campagnes': [72, 7, 0],
#  'analyser': [157, 65, 57],
#  'plus': [867, 516, 630],
#  'demandés': [3, 2, 1],
#  'par': [666, 427, 547],
#  'visiteurs': [4, 0, 1],
#  'identifier': [93, 48, 41],
#  'destinations': [1, 0, 1],
#  'tendance': [7, 0, 4],
#  'alerter': [5, 0, 1],
#  'business': [418, 121, 181],
#  'cas': [70, 86, 78],
#  'comportement': [14, 15, 7],
#  'inattendu': [1, 0, 0],
#  'source': [34, 18, 26],
#  'problème': [10, 16, 5],
#  'recommander': [7, 0, 0],
#  'solution': [52, 45, 118],
#  'définir': [95, 27, 65],
#  'l’objectif': [5, 7, 7],
#  'l’a': [2, 0, 0],
#  'test': [50, 13, 22],
#  'périmètre': [63, 15, 15],
#  'permettant': [117, 62, 107],
#  'd’obtenir': [3, 0, 0],
#  'résultats': [128, 112, 34],
#  'rapides': [4, 2, 3],
#  'fiables': [10, 4, 17],
#  'limitant': [1, 0, 0],
#  'risques': [97, 47, 21],
#  'kpis': [33, 5, 2],
#  'suivre': [82, 14, 21],
#  'mesurer': [24, 10, 5],
#  'efficacement': [10, 4, 10],
#  'impacts': [32, 8, 5],
#  'potentiels': [15, 1, 5],
#  'réaliser': [117, 78, 82],
#  'basées': [10, 12, 9],
#  'significativité': [2, 0, 0],
#  'recommandations': [58, 21, 8],
#  'd': [3251, 2053, 2341],
#  'actions': [99, 24, 29],
#  'ad': [46, 8, 2],
#  'hoc': [44, 8, 1],
#  'exploratoires': [5, 5, 2],
#  'améliorer': [107, 53, 48],
#  'compréhension': [89, 48, 43],
#  'd’un': [114, 78, 106],
#  'domaine': [154, 139, 141],
#  'd’une': [125, 94, 135],
#  'situation': [66, 51, 67],
#  'opportunités': [63, 35, 46],
#  'croissances': [1, 0, 0],
#  'traduire': [22, 14, 7],
#  'plan': [99, 39, 57],
#  'd’actions': [6, 2, 2],
#  'problématiques': [99, 77, 70],
#  'non': [97, 79, 76],
#  'maîtrisées': [1, 0, 0],
#  'date': [60, 54, 28],
#  'parler': [14, 6, 7],
#  'y': [93, 50, 72],
#  'répondre': [86, 89, 88],
#  'environnement': [269, 204, 304],
#  'technique': [126, 124, 248],
#  'tableau': [135, 21, 42],
#  'dataiku': [31, 26, 9],
#  'dss': [1, 4, 1],
#  'bigquery': [15, 9, 33],
#  'elasticsearch': [2, 2, 34],
#  'etl': [41, 9, 113],
#  'interne': [87, 51, 56],
#  'apache': [1, 2, 16],
#  'spark': [13, 53, 161],
#  'on': [94, 38, 70],
#  'yarn': [1, 1, 1],
#  'google': [75, 25, 39],
#  'cloud': [71, 102, 418],
#  'storage': [2, 4, 12],
#  'dataproc': [1, 3, 6],
#  'pub': [2, 2, 6],
#  'sub': [1, 1, 5],
#  'python': [203, 271, 267],
#  'scala': [6, 19, 100],
#  'docker': [6, 19, 68],
#  'github': [4, 8, 24],
#  'gitlabqualificationsformation': [1, 0, 0],
#  'supérieure': [48, 21, 41],
#  'bac': [324, 177, 179],
#  'école': [116, 74, 85],
#  'd’ingénieur': [30, 27, 33],
#  'ou': [958, 655, 833],
#  'spécialisation': [63, 72, 39],
#  'statistiques': [194, 176, 47],
#  'avez': [400, 299, 378],
#  'minimum': [130, 70, 89],
#  'ans': [225, 110, 179],
#  'd’expérience': [22, 8, 33],
#  'dans': [1901, 1188, 1682],
#  'l’analyse': [45, 11, 11],
#  'digital': [126, 95, 85],
#  'êtes': [453, 292, 331],
#  'reconnu': [45, 23, 36],
#  'votre': [818, 443, 667],
#  'rigueur': [99, 62, 43],
#  'excellent': [19, 10, 11],
#  'sens': [137, 80, 101],
#  'bon': [121, 74, 124],
#  'relationnel': [51, 39, 43],
#  'aimez': [71, 43, 51],
#  'travailler': [226, 119, 226],
#  'équipe': [632, 406, 571],
#  'notions': [26, 15, 22],
#  'sql': [284, 111, 214],
#  'maîtrisez': [86, 48, 60],
#  'outil': [127, 64, 34],
#  'bi': [255, 25, 134],
#  'marché': [103, 37, 151],
#  'forte': [119, 58, 99],
#  'fort': [56, 37, 31],
#  'esprit': [175, 111, 108],
#  'analytique': [64, 18, 21],
#  'bases': [123, 53, 141],
#  'solides': [22, 21, 28],
#  'statistique': [38, 38, 18],
#  'savez': [84, 41, 51],
#  'communiquer': [43, 31, 28],
#  'clairement': [2, 2, 1],
#  'vos': [509, 290, 414],
#  'd’analyses': [15, 7, 2],
#  'synthèse': [109, 52, 32],
#  'l’intérêt': [2, 0, 1],
#  'nouveaux': [152, 73, 135],
#  'langages': [63, 51, 76],
#  'tels': [31, 24, 32],
#  'r': [67, 102, 17],
#  'proposer': [96, 62, 48],
#  'nouvelles': [132, 111, 110],
#  'idées': [27, 18, 23],
#  'avancer': [5, 4, 5],
#  'informations': [156, 72, 85],
#  'supplémentaires': [22, 10, 24],
#  'journey': [7, 1, 3],
#  'grandir': [28, 25, 33],
#  'équipes': [515, 201, 332],
#  'dynamique': [110, 69, 93],
#  'exposé': [1, 1, 1],
#  'l’international': [14, 7, 6],
#  'être': [270, 146, 263],
#  'entièrement': [6, 3, 1],
#  'impliqué': [9, 8, 11],
#  'l’aventure': [9, 8, 6],
#  'devenir': [30, 15, 28],
#  'acteur': [92, 49, 55],
#  'réussite': [40, 18, 20],
#  'participation': [60, 44, 43],
#  'vivre': [27, 22, 34],
#  'sud': [12, 3, 6],
#  'cadre': [223, 161, 147],
#  'naturel': [11, 18, 1],
#  'économique': [21, 12, 6],
#  'culturel': [2, 1, 1],
#  'exceptionnel': [2, 1, 10],
#  's’impliquer': [1, 1, 1],
#  'projets': [391, 267, 461],
#  'sociétaux': [6, 10, 4],
#  'orientés': [5, 3, 5],
#  'éducation': [4, 5, 16],
#  'sport': [39, 17, 27],
#  'ecole': [40, 24, 32],
#  'xv': [2, 1, 1],
#  'vp': [1, 1, 7],
#  'green': [1, 5, 8],
#  'accompagner': [179, 68, 129],
#  'start': [26, 7, 25],
#  'up': [48, 9, 44],
#  'accélérateur': [3, 3, 5],
#  'tremplins': [1, 1, 1],
#  'innovation': [127, 92, 92],
#  'tourisme': [3, 1, 4],
#  'bénéficier': [22, 15, 17],
#  'tarifs': [11, 4, 1],
#  'encore': [52, 39, 65],
#  'avantageux': [3, 2, 9],
#  'sites': [52, 14, 19],
#  'profiter': [13, 10, 11],
#  'famille': [14, 10, 15],
#  'amis': [2, 2, 2],
#  'participer': [165, 117, 171],
#  'collègues': [27, 15, 21],
#  'aux': [652, 356, 552],
#  'cours': [53, 34, 34],
#  'offerts': [6, 3, 4],
#  'matchs': [1, 1, 1],
#  'rugby': [2, 2, 2],
#  'provence': [5, 2, 3],
#  'enfin': [44, 21, 29],
#  'nombreux': [60, 28, 32],
#  'évènements': [12, 8, 15],
#  'internes': [120, 43, 78],
#  'company': [27, 15, 23],
#  'breaks': [1, 1, 1],
#  'mensuels': [18, 6, 5],
#  'convention': [9, 2, 16],
#  'annuelle': [11, 4, 5],
#  'etc': [185, 106, 172],
#  'rythment': [1, 8, 1],
#  'vie': [114, 67, 88],
#  'euro': [5, 1, 0],
#  'information': [120, 65, 75],
#  'filiale': [50, 28, 37],
#  'technologique': [82, 48, 134],
#  'crédit': [112, 140, 43],
#  'mutuel': [6, 4, 0],
#  'alliance': [4, 1, 4],
#  'fédérale': [2, 0, 0],
#  'conçoit': [12, 3, 5],
#  'réalise': [11, 7, 4],
#  'maintient': [1, 1, 9],
#  'exploite': [7, 2, 0],
#  'système': [62, 34, 54],
#  'd’information': [21, 10, 24],
#  'commun': [30, 9, 12],
#  'utilisé': [9, 13, 6],
#  'activités': [170, 114, 136],
#  'production': [141, 131, 160],
#  'informatique': [146, 94, 149],
#  'national': [23, 4, 8],
#  'international': [134, 81, 104],
#  'assurées': [1, 0, 0],
#  'environ': [4, 4, 14],
#  'répartis': [21, 12, 15],
#  'géographiques': [5, 1, 25],
#  'strasbourg': [2, 5, 0],
#  'nancy': [1, 0, 0],
#  'dijon': [1, 3, 1],
#  'orléans': [3, 0, 0],
#  'lyon': [31, 13, 36],
#  'lille': [24, 13, 27],
#  'cergy': [1, 0, 0],
#  'val': [6, 0, 0],
#  'fontenay': [1, 0, 0],
#  'paris': [174, 67, 132],
#  'nantes': [34, 18, 25],
#  'l’arrivée': [2, 0, 0],
#  'maturité': [4, 2, 4],
#  'solutions': [268, 236, 430],
#  'informatiques': [67, 17, 24],
#  'automatique': [11, 35, 8],
#  'langage': [75, 87, 42],
#  'ainsi': [257, 134, 137],
#  'qu’un': [10, 2, 4],
#  'apprentissage': [24, 57, 45],
#  'l’exemple': [1, 0, 0],
#  'ouvert': [35, 25, 28],
#  'perspectives': [16, 3, 20],
#  'mieux': [75, 46, 54],
#  'assister': [10, 4, 13],
#  'servir': [8, 2, 5],
#  'leurs': [239, 126, 163],
#  'donc': [19, 27, 25],
#  'décidé': [5, 2, 2],
#  'd’investir': [1, 0, 0],
#  'fortement': [14, 9, 8],
#  'l’informatique': [5, 5, 1],
#  'cognitive': [1, 1, 0],
#  'avons': [64, 40, 82],
#  'été': [43, 19, 23],
#  'première': [83, 42, 67],
#  'mettre': [202, 102, 128],
#  'œuvre': [103, 75, 139],
#  'technologie': [40, 29, 70],
#  'ibm': [4, 0, 3],
#  'watson': [2, 0, 0],
#  'dites': [1, 1, 1],
#  'cognitives': [3, 0, 0],
#  'déployées': [4, 0, 7],
#  'assistants': [1, 1, 0],
#  'virtuels': [2, 0, 0],
#  'chatbot': [1, 2, 2],
#  'analyseurs': [1, 0, 0],
#  'd’emails': [1, 0, 0],
#  'assistant': [9, 2, 1],
#  'vocal': [1, 1, 0],
#  'téléphonique': [11, 3, 4],
#  'sein': [425, 241, 338],
#  'secteur': [108, 73, 53],
#  'innovant': [21, 15, 21],
#  'rejoignez': [112, 102, 88],
#  'l’équipe': [93, 63, 91],
#  'exploitation': [76, 59, 67],
#  'architectures': [9, 11, 53],
#  'l’architecture': [7, 5, 25],
#  'applicative': [3, 0, 6],
#  'créer': [81, 51, 79],
#  'outils': [590, 233, 265],
#  'récoltées': [2, 2, 0],
#  'd’enrichir': [3, 0, 1],
#  'processus': [175, 72, 165],
#  'métiers': [392, 208, 236],
#  'selon': [63, 44, 52],
#  'ces': [161, 128, 147],
#  'composants': [15, 3, 29],
#  'déclinent': [1, 5, 1],
#  'technologies': [115, 139, 257],
#  'c': [227, 150, 204],
#  'serveur': [2, 0, 1],
#  'nosql': [10, 14, 73],
#  'kibana': [6, 4, 7],
#  'kafka…': [1, 0, 1],
#  'intégré': [48, 22, 35],
#  'dizaine': [5, 6, 5],
#  'personnes': [124, 84, 135],
#  'seront': [117, 82, 75],
#  'relation': [67, 31, 36],
#  'gestion': [336, 135, 208],
#  'précisément': [6, 10, 4],
#  'concevoir': [76, 38, 108],
#  'rédiger': [48, 7, 36],
#  'spécifications': [47, 4, 48],
#  'fonctionnelles': [58, 5, 42],
#  'applicatives': [16, 1, 7],
#  'techniques': [251, 202, 282],
#  'applications': [56, 69, 89],
#  'intranet': [3, 0, 0],
#  'd’exploration': [4, 0, 0],
#  'restitution': [43, 24, 17],
#  'modéliser': [33, 11, 27],
#  'décisionnel': [37, 6, 9],
#  'dashboard': [49, 10, 4],
#  'apporter': [65, 26, 27],
#  'support': [95, 39, 82],
#  'organiser': [49, 16, 19],
#  'recette': [49, 2, 28],
#  'gérer': [82, 19, 50],
#  'demandes': [36, 9, 8],
#  'd’évolution': [10, 3, 12],
#  'mode': [46, 13, 36],
#  'respect': [75, 24, 51],
#  'management': [152, 77, 151],
#  'qualité': [294, 115, 201],
#  'allez': [15, 6, 6],
#  'chez': [236, 102, 170],
#  'noustélétravail': [1, 0, 0],
#  'jours': [89, 34, 83],
#  'semaine': [49, 22, 39],
#  'rémunération': [46, 20, 43],
#  'fixe': [20, 9, 5],
#  'versée': [1, 0, 0],
#  'mois': [172, 116, 91],
#  'rtt': [32, 8, 25],
#  'intéressement': [25, 8, 8],
#  'abondement': [2, 2, 1],
#  'épargne': [21, 6, 11],
#  'perco': [1, 0, 0],
#  'contrat': [185, 87, 89],
#  'santé': [80, 90, 56],
#  'prévoyance': [19, 10, 15],
#  'retraite': [12, 7, 6],
#  'supplémentaire': [4, 1, 1],
#  'l’employeur': [1, 0, 3],
#  'conditions': [41, 13, 15],
#  'bancaires': [24, 13, 7],
#  'assurances': [30, 32, 13],
#  'préférentielles': [2, 0, 0],
#  'politique': [65, 25, 45],
#  'parentale': [1, 1, 0],
#  'avantageuse': [1, 1, 5],
#  'allons': [3, 3, 1],
#  'aimer': [3, 1, 1],
#  'issu': [31, 10, 16],
#  'formation': [311, 172, 250],
#  'maitrisez': [42, 21, 28],
#  'base': [110, 69, 83],
#  'orientée': [9, 5, 14],
#  'programmation': [57, 61, 65],
#  'objet': [5, 5, 4],
#  'type': [185, 102, 117],
#  'plaira': [3, 1, 0],
#  'alors': [82, 62, 70],
#  'bien': [142, 75, 146],
#  'évidemment': [6, 2, 0],
#  'préférera': [3, 1, 0],
#  'curieux': [64, 43, 56],
#  'innovations': [16, 10, 1],
#  'technologiques': [42, 27, 63],
#  'prêt': [36, 18, 11],
#  'relever': [35, 13, 45],
#  'défis': [30, 18, 52],
#  'faisant': [8, 3, 6],
#  'preuve': [82, 56, 35],
#  'd’écoute': [14, 2, 0],
#  'car': [17, 13, 6],
#  'permettra': [31, 22, 46],
#  'mener': [49, 29, 37],
#  'également': [111, 95, 105],
#  'capacités': [83, 35, 46],
#  'd’analyse': [67, 26, 29],
#  'souci': [8, 4, 15],
#  'normes': [6, 3, 19],
#  'standards': [24, 12, 36],
#  'appréciez': [14, 15, 11],
#  'apprendre': [35, 24, 22],
#  'mais': [82, 71, 82],
#  'collaboration': [102, 66, 95],
#  'cette': [196, 129, 201],
#  'offre': [197, 107, 115],
#  'faite': [3, 6, 5],
#  'complémentaires': [51, 33, 44],
#  'basé': [62, 38, 35],
#  'pourvoir': [46, 18, 11],
#  'cdi': [139, 47, 107],
#  'dès': [48, 25, 31],
#  'possible': [95, 39, 65],
#  'faisons': [8, 2, 15],
#  'connaissance': [288, 136, 160],
#  'régie': [4, 3, 4],
#  'plurimédia': [2, 0, 0],
#  'tf': [12, 7, 8],
#  'publicité': [13, 2, 3],
#  'commercialise': [12, 3, 3],
#  'espaces': [17, 1, 4],
#  'publicitaires': [20, 0, 0],
#  'supports': [27, 5, 9],
#  'médias': [16, 8, 5],
#  'télévision': [7, 3, 2],
#  'écrans': [4, 0, 0],
#  'classique': [3, 2, 0],
#  'dispositifs': [23, 8, 11],
#  'parrainage': [5, 0, 0],
#  'chaînes': [7, 3, 10],
#  'tmc': [2, 1, 1],
#  'tfx': [2, 1, 1],
#  'séries': [6, 17, 1],
#  'films': [2, 9, 1],
#  'lci': [2, 1, 1],
#  'tv': [10, 7, 2],
#  'breizh': [2, 0, 0],
#  'ushuaïa': [2, 0, 0],
#  'histoire': [8, 1, 3],
#  'depuis': [135, 57, 95],
#  'peu': [8, 5, 12],
#  'chaîne': [24, 25, 48],
#  'réunionnaise': [2, 0, 0],
#  'antenne': [3, 1, 0],
#  'réunion': [3, 0, 0],
#  'radios': [7, 0, 0],
#  'indés': [2, 0, 0],
#  'm': [41, 13, 22],
#  'radio': [4, 0, 0],
#  'outre': [17, 4, 6],
#  'mer': [6, 0, 0],
#  'autour': [83, 61, 94],
#  'déclinaisons': [2, 0, 0],
#  'digitales': [25, 24, 14],
#  'commercialisées': [3, 0, 0],
#  'assets': [6, 2, 0],
#  'digitaux': [21, 15, 7],
#  'mytf': [2, 0, 1],
#  'poursuivant': [2, 0, 0],
#  'déploiement': [58, 46, 77],
#  'stratégie': [130, 65, 69],
#  'digitale': [94, 49, 94],
#  'pc': [5, 0, 1],
#  'mobile': [40, 6, 17],
#  'tablette': [2, 0, 0],
#  'travers': [100, 69, 76],
#  'diversité': [119, 82, 87],
#  'attractivité': [5, 0, 0],
#  'propose': [46, 24, 25],
#  'ses': [378, 204, 327],
#  'annonceurs': [6, 5, 1],
#  'modes': [16, 10, 7],
#  'expression': [19, 3, 3],
#  'différenciés': [2, 0, 0],
#  'adaptés': [22, 9, 8],
#  'besoins': [274, 113, 165],
#  'revenu': [5, 1, 0],
#  'piloter': [56, 11, 23],
#  'inventaires': [5, 1, 0],
#  'offres': [90, 44, 57],
#  'adserving': [2, 0, 0],
#  'afin': [309, 137, 197],
#  'opérer': [9, 1, 5],
#  'appliquer': [8, 12, 8],
#  'analyste': [68, 1, 1],
#  'aura': [26, 22, 5],
#  'suivantes': [107, 68, 85],
#  'suivi': [252, 85, 83],
#  'audiences': [4, 5, 2],
#  'reporting': [136, 10, 38],
#  'replay': [4, 1, 0],
#  'segmentée…': [2, 0, 0],
#  'vidéos': [2, 1, 1],
#  'vues': [5, 0, 1],
#  'remplissage': [2, 0, 0],
#  'impressions': [4, 0, 0],
#  'maintenance': [54, 43, 69],
#  'adserver': [2, 0, 0],
#  'freewheel': [4, 0, 0],
#  'assurer': [208, 50, 185],
#  'correcte': [2, 0, 0],
#  'diffusion': [34, 11, 5],
#  'mise': [274, 146, 298],
#  'jour': [120, 40, 53],
#  'commerciaux': [37, 7, 22],
#  'avant': [55, 36, 39],
#  'disponible': [12, 4, 7],
#  'réservation': [3, 0, 0],
#  'ops': [11, 1, 7],
#  'sponsoring': [4, 0, 2],
#  'adserve': [1, 0, 0],
#  'localisation': [74, 40, 40],
#  'boulogne': [9, 7, 4],
#  'billancourt': [7, 1, 4],
#  'atouts': [34, 23, 15],
#  'différencevous': [1, 1, 0],
#  'préparez': [29, 23, 7],
#  'economie': [2, 2, 0],
#  'revenue': [3, 1, 0],
#  'commerce': [129, 35, 20],
#  'université': [39, 33, 33],
#  'équivalent': [55, 31, 28],
#  'maitriser': [6, 2, 3],
#  'excellente': [13, 4, 13],
#  'maîtrise': [183, 127, 119],
#  'excel': [113, 12, 6],
#  'software': [29, 8, 17],
#  'objects': [8, 0, 2],
#  'aise': [43, 11, 22],
#  'adservers': [2, 0, 0],
#  'dfp': [2, 0, 0],
#  'faites': [49, 36, 19],
#  'raisonnement': [3, 0, 2],
#  'structuré': [10, 2, 11],
#  'réelle': [16, 29, 23],
#  'capacité': [273, 106, 141],
#  'transversalité': [7, 2, 0],
#  'fonctionnement': [37, 13, 53],
#  'aisance': [35, 13, 25],
#  'relationnelle': [32, 9, 28],
#  'adaptation': [34, 11, 15],
#  'travail': [296, 183, 279],
#  'font': [43, 22, 43],
#  'partie': [69, 36, 109],
#  'mène': [5, 3, 1],
#  'engagée': [34, 10, 15],
#  'garantir': [49, 22, 53],
#  'équité': [9, 1, 9],
#  'ouverts': [30, 19, 36],
#  'handicap': [74, 50, 82],
#  'région': [35, 19, 16],
#  'île': [15, 2, 3],
#  'recherche': [173, 179, 98],
#  'responsable': [143, 44, 85],
#  'professionnelle': [73, 47, 65],
#  'ptn': [2, 0, 0],
#  'pôle': [90, 39, 58],
#  'transformation': [176, 82, 196],
#  'numérique': [50, 53, 84],
#  'direction': [226, 121, 65],
#  'sous': [107, 66, 50],
#  'responsabilité': [65, 38, 32],
#  'pilote': [12, 6, 4],
#  'liés': [36, 13, 34],
#  'feuille': [9, 5, 13],
#  'route': [14, 6, 15],
#  'pfpa': [2, 0, 0],
#  'il': [197, 120, 248],
#  'assure': [32, 6, 23],
#  'appui': [14, 13, 6],
#  'documentation': [41, 25, 51],
#  'modélisation': [93, 86, 91],
#  'liée': [5, 3, 4],
#  'titre': [35, 27, 18],
#  'elle': [105, 45, 116],
#  'accompagne': [51, 27, 46],
#  'chefs': [18, 6, 10],
#  'leur': [322, 161, 245],
#  'apporte': [18, 13, 16],
#  'conseil': [89, 53, 100],
#  'expert': [22, 28, 21],
#  'ressources': [54, 16, 26],
#  'cohérence': [38, 6, 16],
#  'lignes': [20, 6, 1],
#  'directrices': [6, 0, 0],
#  'liées': [26, 23, 26],
#  'gouvernance': [58, 13, 35],
#  'compétence': [56, 27, 46],
#  'régionale': [6, 15, 1],
#  'carif': [1, 0, 0],
#  'recensement': [4, 0, 0],
#  'l’offre': [7, 6, 10],
#  'sa': [173, 98, 123],
#  'dimension': [11, 20, 9],
#  'chantiers': [7, 6, 8],
#  'applicatifs': [5, 9, 11],
#  'equiper': [2, 0, 0],
#  'métier': [293, 181, 170],
#  'cartographie': [16, 4, 14],
#  'l’identification': [10, 5, 5],
#  'sources': [72, 43, 74],
#  'référentiels': [14, 3, 13],
#  'maîtres': [2, 1, 3],
#  'appuyer': [2, 5, 2],
#  'formalisation': [5, 2, 4],
#  'prioritaires': [3, 0, 2],
#  'l’outillage': [1, 0, 0],
#  'd’assurer': [7, 4, 8],
#  'l’intégrité': [3, 0, 2],
#  'sécurité': [61, 46, 89],
#  'conduire': [10, 3, 8],
#  'renforcement': [3, 24, 1],
#  'place': [312, 136, 244],
#  'décisionnels': [20, 4, 10],
#  'datawarehouses': [1, 0, 2],
#  'datamarts': [9, 0, 4],
#  'tableaux': [136, 19, 17],
#  'bord': [143, 17, 19],
#  'lien': [123, 41, 32],
#  'profilcompétences': [1, 1, 1],
#  'requises': [39, 34, 27],
#  'enjeux': [122, 58, 84],
#  'cycle': [33, 34, 42],
#  'conceptuelle': [2, 3, 0],
#  'n’est': [11, 3, 3],
#  'requise': [17, 10, 5],
#  'savoir': [123, 85, 91],
#  'méthodologiques': [6, 3, 4],
#  'matière': [49, 28, 44],
#  'numériques': [26, 25, 43],
#  'utilisateurs': [125, 28, 58],
#  'poser': [2, 0, 0],
#  'rapidement': [27, 14, 24],
#  'diagnostic': [5, 5, 6],
#  'fonctionnels': [21, 3, 32],
#  'limites': [17, 3, 6],
#  'avérée': [9, 6, 2],
#  'aptitude': [6, 8, 3],
#  'stratégique': [81, 13, 27],
#  'force': [160, 65, 74],
#  'proposition': [143, 75, 66],
#  'd’initiative': [13, 7, 5],
#  'goût': [51, 12, 19],
#  'l’action': [5, 0, 0],
#  'l’innovation': [19, 21, 7],
#  'l’usager': [1, 0, 0],
#  'public': [33, 24, 25],
#  'pédagogie': [16, 11, 9],
#  'l’explication': [1, 0, 0],
#  'spécialistes': [23, 11, 32],
#  'pro': [25, 2, 9],
#  'autonomie': [94, 59, 71],
#  'adaptabilité': [12, 13, 2],
#  'dynamisme': [19, 11, 25],
#  'réactivité': [27, 11, 12],
#  'sauf': [5, 0, 0],
#  'mention': [2, 0, 0],
#  'durée': [80, 63, 33],
#  'déterminée': [2, 2, 1],
#  'cdd': [21, 9, 2],
#  'cet': [16, 5, 18],
#  'emploi': [50, 28, 15],
#  'priorité': [6, 2, 15],
#  'agents': [14, 7, 28],
#  'titulaires': [4, 0, 0],
#  'fonction': [107, 42, 49],
#  'publique': [18, 1, 0],
#  'voie': [8, 2, 0],
#  'mutation': [8, 8, 1],
#  'détachement': [6, 0, 0],
#  'inscrits': [3, 1, 2],
#  'liste': [13, 3, 2],
#  'qu’aux': [4, 1, 1],
#  'contractuels': [5, 0, 4],
#  'décret': [2, 0, 0],
#  'n°': [27, 3, 1],
#  'février': [9, 12, 3],
#  'pris': [20, 4, 12],
#  'application': [74, 36, 47],
#  'article': [12, 7, 3],
#  'loi': [4, 2, 0],
#  'janvier': [50, 27, 12],
#  'modifiée': [3, 0, 0],
#  'portant': [2, 7, 0],
#  'dispositions': [2, 0, 1],
#  'statutaires': [2, 0, 0],
#  'relatives': [15, 1, 8],
#  'territoriale': [4, 2, 0],
#  'relatif': [2, 0, 1],
#  'construisons': [17, 6, 8],
#  'lieu': [55, 43, 24],
#  'demain': [68, 39, 55],
#  'installée': [4, 2, 1],
#  'l’éco': [3, 0, 1],
#  'quartier': [4, 0, 1],
#  'docks': [3, 0, 0],
#  'saint': [42, 22, 4],
#  'ouen': [5, 1, 1],
#  'bâtiment': [23, 19, 7],
#  'hqe': [4, 0, 0],
#  'télétravail': [140, 59, 129],
#  'salle': [18, 10, 20],
#  'services…': [2, 0, 0],
#  'réinventé': [2, 0, 0],
#  'confiance': [50, 18, 43],
#  'humaines': [30, 9, 9],
#  'active': [19, 8, 11],
#  'ile': [47, 14, 19],
#  'lutte': [19, 14, 13],
#  'contre': [21, 11, 13],
#  'toutes': [123, 63, 110],
#  'formes': [12, 5, 3],
#  'discriminations': [5, 1, 1],
#  'vise': [6, 5, 3],
#  'diversifier': [3, 6, 1],
#  'candidatures': [19, 15, 7],
#  'reconnaît': [6, 0, 3],
#  'talents': [97, 54, 78],
#  'handi': [10, 2, 0],
#  'accessible': [25, 10, 19],
#  'régional': [3, 7, 3],
#  'mondial': [57, 42, 36],
#  'relay': [4, 0, 0],
#  'qu': [121, 81, 104],
#  'simple': [24, 5, 13],
#  'colis': [4, 0, 0],
#  'offrons': [22, 11, 41],
#  'expédition': [1, 0, 0],
#  'livraison': [25, 6, 15],
#  'rapide': [15, 9, 4],
#  'vertueux': [7, 2, 2],
#  'réseau': [106, 74, 43],
#  'points': [39, 10, 4],
#  'relais': [5, 1, 0],
#  'lockers': [1, 0, 0],
#  'créateur': [8, 7, 5],
#  'liens': [7, 2, 0],
#  'entre': [102, 58, 84],
#  'commerçants': [9, 6, 2],
#  'consommateurs': [34, 10, 13],
#  'précurseurs': [1, 0, 0],
#  'tendances': [25, 10, 15],
#  'écoute': [30, 14, 22],
#  'portés': [1, 1, 1],
#  'contexte': [83, 66, 66],
#  'constant': [5, 1, 2],
#  'hors': [14, 12, 10],
#  'domicile': [6, 2, 0],
#  'ambitionnons': [1, 1, 0],
#  'étendre': [5, 8, 0],
#  'préférence': [6, 3, 10],
#  'challenge': [34, 13, 15],
#  'basés': [15, 4, 6],
#  'relèvent': [1, 0, 0],
#  'passion': [51, 26, 27],
#  'accomplissement': [3, 0, 0],
#  'collaboratifs': [8, 4, 5],
#  'ambiance': [20, 12, 19],
#  'pleine': [27, 13, 25],
#  'pep': [1, 0, 0],
#  'recherchons': [89, 65, 73],
#  'futur': [61, 19, 52],
#  'relayeuses': [2, 0, 0],
#  'relayeurs': [2, 0, 0],
#  'prendre': [67, 36, 32],
#  'part': [32, 22, 41],
#  'suite': [29, 15, 14],
#  'côtés': [16, 14, 24],
#  'si': [264, 104, 164],
#  'comme': [154, 74, 128],
#  'convaincu': [15, 7, 6],
#  'n': [109, 47, 73],
#  'attendez': [4, 8, 10],
#  'découvrez': [6, 2, 3],
#  'prochain': [19, 3, 5],
#  'h': [253, 124, 118],
#  'f': [205, 109, 99],
#  'excellence': [32, 31, 53],
#  'opérationnelle': [48, 34, 37],
#  'évoluer': [115, 55, 97],
#  'process': [90, 44, 78],
#  'globale': [30, 18, 16],
#  'notamment': [114, 66, 80],
#  'celle': [16, 4, 10],
#  'relative': [3, 5, 6],
#  'amélioration': [77, 47, 43],
#  'efficience': [10, 2, 3],
#  'opérations': [62, 23, 26],
#  'cœur': [122, 68, 104],
#  'directions': [51, 26, 26],
#  'opération': [5, 6, 2],
#  'industrielle': [14, 11, 18],
#  'soutenez': [1, 0, 2],
#  'activement': [20, 11, 28],
#  'directeurs': [3, 5, 2],
#  'industriel': [25, 27, 19],
#  'initiatives': [24, 23, 30],
#  'stratégiques': [48, 19, 21],
#  'visant': [29, 11, 26],
#  'continue': [41, 22, 57],
#  'opérationnels': [40, 24, 17],
#  ...}

# %% [markdown]
# #### Transformer le dictionnaire en dataframe

# %%
texto = pd.DataFrame.from_dict(motex, orient='index')
texto.head(3)
# Out:
#                  0     1      2
# description    160   114    206
# de           13556  8280  10562
# l             2699  1656   2207

# %%
texto.reset_index(inplace=True)
texto.head(3)
# Out:
#          index      0     1      2
# 0  description    160   114    206
# 1           de  13556  8280  10562
# 2            l   2699  1656   2207

# %%
(texto.columns)
# Out:
# Index(['index', 0, 1, 2], dtype='object')

# %%
texto.rename(columns = {'index':'mot',
                        0:'Data analyst', 
                        1:'Data scientist',
                        2:'Data engineer'}, inplace = True)

# %%
texto.head(3)
# Out:
#            mot  Data analyst  Data scientist  Data engineer
# 0  description           160             114            206
# 1           de         13556            8280          10562
# 2            l          2699            1656           2207

# %% [markdown]
# #### Création d'une list des outils de la data science

# %%
word = ['sql', 'bi', 'python', 'sas', 'etl', 'oracle', 'machinelearning', 'rstudio', 'api', 'power', 
        'talend', 'mysql', 'r', 'java', 'js', 'javascrispt', 'mongodb', 'cloud', 'datawarehouse',
       'datamarts', 'dataviz', 'qlik', 'nosql', 'Datavisualisation', 'query', 'datalake', 'bigquery',
       'postgresql', 'warehousing', 'reporting', 'css', 'html', 'kpi', 'api', 'reactjs', 'nlp', 'pandas',
       'scikit', 'tensorflow', 'numpy', 'matplotlib', 'seaborn', 'scala', 'docker', 'github', 'apache',
       'spark', 'tableau', 'dataiku', 'mining', 'datamining', 'Storytelling', 'crm', 'aws', 'azure', 'informatica',
       'spreadsheet', 'classification', 'clustering', 'rgpd', 'dashboards', 'jupyter', 'nltk', 'ggplot', 'microsoft',
       'matlab', 'scipy', 'hadoop', 'php', 'linux']

# %%
len(word)
# Out:
# 70

# %% [markdown]
# #### Garder uniquement les lignes contenant les mots dans la liste "word"

# %%
fss = texto[texto.mot.isin(word) == True]

# %%
fss
# Out:
#             mot  Data analyst  Data scientist  Data engineer
# 127         crm            77              36             23
# 263     tableau           135              21             42
# 264     dataiku            31              26              9
# 266    bigquery            15               9             33
# 268         etl            41               9            113
# ...         ...           ...             ...            ...
# 11782    ggplot             0               1              0
# 11812       nlp             0              59              7
# 12221        js             0               5              8
# 14269      nltk             0               1              0
# 15793   reactjs             0               0              2
#
# [66 rows x 4 columns]

# %%
fss.shape
# Out:
# (66, 4)

# %% [markdown]
# #### Exportation de la base de données en format excel

# %%
fss.to_excel(r'final result.xlsx')

# %% [markdown]
# ##### Tri décroissant en fonction de compétences techniques les plus recherchées pour le poste Data Analyst

# %%
fss.sort_values(by='Data analyst', ascending=False).head(6)
# Out:
#             mot  Data analyst  Data scientist  Data engineer
# 311         sql           284             111            214
# 314          bi           255              25            134
# 280      python           203             271            267
# 688   reporting           136              10             38
# 263     tableau           135              21             42
# 1887      power           128              14             51

# %% [markdown]
# ##### Tri décroissant en fonction de compétences techniques les plus recherchées pour le poste Data Scientist

# %%
fss.sort_values(by='Data scientist', ascending=False).head(6)
# Out:
#           mot  Data analyst  Data scientist  Data engineer
# 280    python           203             271            267
# 311       sql           284             111            214
# 275     cloud            71             102            418
# 333         r            67             102             17
# 11812     nlp             0              59              7
# 1919    azure            39              59            237

# %% [markdown]
# ##### Tri décroissant en fonction de compétences techniques les plus recherchées pour le poste Data Engineer

# %%
fss.sort_values(by='Data engineer', ascending=False).head(6)
# Out:
#          mot  Data analyst  Data scientist  Data engineer
# 275    cloud            71             102            418
# 280   python           203             271            267
# 1919   azure            39              59            237
# 311      sql           284             111            214
# 271    spark            13              53            161
# 314       bi           255              25            134
